# %% [markdown]
# # **Install the required modules**

# %%
# !pip install youtube-transcript-api
# !pip install openai
# !pip install pytube
# !pip install openai-whisper
# !pip install google-generativeai
# !pip install yt-dlp
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.7.4)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.2
# Collecting openai
#   Downloading openai-1.35.14-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.4 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.35.14
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 930.3 kB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
# Collecting openai-whisper
#   Downloading openai-whisper-20231117.tar.gz (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.3.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.3.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper) (3.15.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->openai-whisper)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->openai-whisper)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->openai-whisper)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->openai-whisper)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->openai-whisper)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->openai-whisper)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->openai-whisper)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801359 sha256=e829e19c990a15de86a8ddb145d616da92e11483953db61600978062a5492d8c
#   Stored in directory: /root/.cache/pip/wheels/d0/85/e1/9361b4cbea7dd4b7f6702fa4c3afc94877952eeb2b62f45f56
# Successfully built openai-whisper
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openai-whisper
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 openai-whisper-20231117 tiktoken-0.7.0
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.4)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.16.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.84.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.4->google-generativeai) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.63.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.1.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.20.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.7.4)
# Collecting yt-dlp
#   Downloading yt_dlp-2024.7.16-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.1 MB/s eta 0:00:00
# Collecting brotli (from yt-dlp)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2024.7.4)
# Collecting mutagen (from yt-dlp)
#   Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 25.8 MB/s eta 0:00:00
# Collecting pycryptodomex (from yt-dlp)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.0 MB/s eta 0:00:00
# Collecting requests<3,>=2.32.2 (from yt-dlp)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.0.7)
# Collecting websockets>=12.0 (from yt-dlp)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.7)
# Installing collected packages: brotli, websockets, requests, pycryptodomex, mutagen, yt-dlp
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed brotli-1.1.0 mutagen-1.47.0 pycryptodomex-3.20.0 requests-2.32.3 websockets-12.0 yt-dlp-2024.7.16

# %% [markdown]
# # **Import the modules**

# %%
import google.generativeai as genai
from openai import OpenAI
import os
from pytube import YouTube
from youtube_transcript_api import YouTubeTranscriptApi

# %% [markdown]
# # **Configuring the Gemini API**

# %%
# Configure i.e loading the API Key for communication.
genai.configure(api_key="API_KEY")

# %% [markdown]
# # **Configuring the OpenAI API**

# %%
import openai
openai.api_key = "API_KEY"
client = openai.OpenAI(api_key=openai.api_key) # Pass the API key to the constructor

# %% [markdown]
# # **Conversion of Video into Audio file for Text conversion using OpenAI**

# %%
import os
import subprocess

def download_and_rename_audio(url, new_name="audio1"):
    # Step 1: Download the video and extract audio
    command = ['yt-dlp', '--extract-audio', '--audio-format', 'mp3', '--output', f'{new_name}.%(ext)s', url]
    subprocess.run(command, check=True)

    # Step 2: Find the downloaded audio file
    filenames = os.listdir('.')
    old_path = None
    for filename in filenames:
        if filename.startswith(new_name) and filename.endswith('.mp3'):
            old_path = filename
            break

    if old_path is None:
        print("Error: No downloaded audio file found.")
        return None

    # Step 3: Store the new path
    new_file_path = os.path.join('.', old_path)
    print(f"New file path: {new_file_path}")
    return new_file_path

# %% [markdown]
# # **Getting the Transcript of the video provided**

# %%
# !pip install yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2024.7.16)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2024.7.4)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (3.20.0)
# Requirement already satisfied: requests<3,>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.0.7)
# Requirement already satisfied: websockets>=12.0 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.7)

# %%
def get_transcript_text(video_id):
    try:
        # Retrieve the transcript
        print("In try")
        transcript = YouTubeTranscriptApi.get_transcript('en', video_id)
        print("In try")

        # Extract and print only the text
        transcript_text = ' '.join([entry['text'] for entry in transcript])
        return transcript_text
    except Exception as e:
        # print(f"Error: {e}")
        print("Error Occured while getting transcript")
        print("Using OpenAI to convert the YouTube video into text")
        video_url = f"https://www.youtube.com/watch?v={video_id}"

        # Download the video
        download_and_rename_audio(video_url)
        # print("The Path of downloaded file is /content/vid1.mp4")

# %% [markdown]
# # **Audio To Text using OpenAI**

# %%
get_transcript_text("_Ki4bS4V2gQ")
# Out:
# In try
# Error Occured while getting transcript
# Using OpenAI to convert the YouTube video into text
# New file path: ./audio1.mp3

# %%
# !pip install git+https://github.com/openai/whisper.git
# !apt update && apt install -y ffmpeg
# !apt update && apt install -y ffmpeg

# %%
import whisper
import time

# Load the smallest Whisper model for faster processing
model = whisper.load_model("tiny")

# Path to the audio file
audio_file_path = "/content/audio1.mp3"

# Start timing
start_time = time.time()

# Transcribe the audio file
result = model.transcribe(audio_file_path)

# End timing
end_time = time.time()

# Print the transcription and processing time
print("Transcription:", result["text"])
print("Processing time:", end_time - start_time, "seconds")
# Out:
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:01<00:00, 51.9MiB/s]
# Transcription:  This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product. CMF is a new budget sub brand of the company nothing so we're talking a phone that costs 200 pounds or 250 dollars and it's actually a little bit crazy what these guys have just pulled off for that price. I mean the first thing I'll notice is this doesn't feel like just a single product launch. This is an entire ecosystem and it's really fascinating one. So let's get the phone out first. There's a Lanyard which is not something you tend to see launch with a phone. One case two cases no three cases a card wallet I guess that's for the back of the phone. There's a stand the Buds Pro 2 and then the watch Pro 2. It all feels very new because we've seen plenty of budget phones before but what you don't often get is a budget accessory ecosystem like this all designed to work specifically around that budget phone as the centerpiece. Everything has well on one hand a slightly cheap thin plastic key feel to it but then on the other hand it's all really tastefully designed. It kind of feels like all of these products have had high end thought and care put into them even if the physical materials and the finish are more basic. So like these are the CMF Buds 2 Pro and even though they're very light and clearly not a luxury item they still feel sophisticated and intentional in their design. Not like a cheap version of something that the company would rather you buy and then the watch Pro 2. Yeah it's slick clean. You never want to watch to go too crazy on design because then it won't match your outfits. So this feels like a pretty appropriate level to me. Right let's get into this phone it's a thin package so we all know what that means. Okay so the device is on top and below that is a generic white USB C to C cable which you should be able to use to transfer everything from the old phone and then an orange sim ejector. Right heel time. And right off the bat it's pretty clear that this is not your normal phone and it's not just that it looks different because you know these cases that I showed you. These are actually back plates. So if you look inside the packaging they came in you'll see a bunch of other stuff like this tool which is both a sim ejector and a screwdriver that allows you to take off these four screws on the back of your phone after which you unwind this circular piece and you're played pops off and this is a pretty big deal for a number of reasons. One that repairing this phone is going to be a lot easier and I hope cheaper than almost any other phone but that part's not confirmed. To that you don't need a case anymore you can actually use your phone naked, guilt-free knowing that if you ever do do something stupid you can just swap the back plate out for, I'm not even that much money, 29 pounds is what they're charging for these kits including the tools. The third thing is it means you can mix a match. So I really like this orange back. It swaps out the slightly cheap feeling very scratchable plastic for a more grippy, less scratchable vegan leather type finish and it's bright orange so let's put it on. But then I'm looking at the orange sim tray, the orange circle screw thing and the silver screws that come with it and thinking silver screws are pretty nice but for the other parts I think I prefer the black ones so I have just created my own two-tone finish on my phone and that's actually sick but the best part of this is that nothing has actually gone one step further to actually create an ecosystem around these weird screws and I don't even know what to call this. Now on this is the circle spinny thing. So if I want a phone stand for example unscrew your circle spinny thing and screw this down then and yeah the standard self isn't anything particularly special. It's not breaking new grounds in material science but if you decide that you want a phone stand then what better way to have a phone stand  ...
# Processing time: 41.521584272384644 seconds

# %%
result
# Out:
# {'text': " This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product. CMF is a new budget sub brand of the company nothing so we're talking a phone that costs 200 pounds or 250 dollars and it's actually a little bit crazy what these guys have just pulled off for that price. I mean the first thing I'll notice is this doesn't feel like just a single product launch. This is an entire ecosystem and it's really fascinating one. So let's get the phone out first. There's a Lanyard which is not something you tend to see launch with a phone. One case two cases no three cases a card wallet I guess that's for the back of the phone. There's a stand the Buds Pro 2 and then the watch Pro 2. It all feels very new because we've seen plenty of budget phones before but what you don't often get is a budget accessory ecosystem like this all designed to work specifically around that budget phone as the centerpiece. Everything has well on one hand a slightly cheap thin plastic key feel to it but then on the other hand it's all really tastefully designed. It kind of feels like all of these products have had high end thought and care put into them even if the physical materials and the finish are more basic. So like these are the CMF Buds 2 Pro and even though they're very light and clearly not a luxury item they still feel sophisticated and intentional in their design. Not like a cheap version of something that the company would rather you buy and then the watch Pro 2. Yeah it's slick clean. You never want to watch to go too crazy on design because then it won't match your outfits. So this feels like a pretty appropriate level to me. Right let's get into this phone it's a thin package so we all know what that means. Okay so the device is on top and below that is a generic white USB C to C cable which you should be able to use to transfer everything from the old phone and then an orange sim ejector. Right heel time. And right off the bat it's pretty clear that this is not your normal phone and it's not just that it looks different because you know these cases that I showed you. These are actually back plates. So if you look inside the packaging they came in you'll see a bunch of other stuff like this tool which is both a sim ejector and a screwdriver that allows you to take off these four screws on the back of your phone after which you unwind this circular piece and you're played pops off and this is a pretty big deal for a number of reasons. One that repairing this phone is going to be a lot easier and I hope cheaper than almost any other phone but that part's not confirmed. To that you don't need a case anymore you can actually use your phone naked, guilt-free knowing that if you ever do do something stupid you can just swap the back plate out for, I'm not even that much money, 29 pounds is what they're charging for these kits including the tools. The third thing is it means you can mix a match. So I really like this orange back. It swaps out the slightly cheap feeling very scratchable plastic for a more grippy, less scratchable vegan leather type finish and it's bright orange so let's put it on. But then I'm looking at the orange sim tray, the orange circle screw thing and the silver screws that come with it and thinking silver screws are pretty nice but for the other parts I think I prefer the black ones so I have just created my own two-tone finish on my phone and that's actually sick but the best part of this is that nothing has actually gone one step further to actually create an ecosystem around these weird screws and I don't even know what to call this. Now on this is the circle spinny thing. So if I want a phone stand for example unscrew your circle spinny thing and screw this down then and yeah the standard self isn't anything particularly special. It's not breaking new grounds in material science but if you decide that you want a phone stand then what better way to have a phone stand that  ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 6.4,
#    'text': " This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product.",
#    'tokens': [50364,
#     639,
#     307,
#     264,
#     777,
#     6693,
#     20424,
#     37,
#     2593,
#     472,
#     293,
#     286,
#     500,
#     380,
#     584,
#     341,
#     588,
#     2049,
#     457,
#     286,
#     519,
#     341,
#     307,
#     257,
#     14017,
#     1674,
#     13,
#     50684],
#    'temperature': 0.0,
#    'avg_logprob': -0.19719823201497397,
#    'compression_ratio': 1.6280701754385964,
#    'no_speech_prob': 0.006479488220065832},
#   {'id': 1,
#    'seek': 0,
#    'start': 6.4,
#    'end': 12.0,
#    'text': " CMF is a new budget sub brand of the company nothing so we're talking a phone that costs 200 pounds or",
#    'tokens': [50684,
#     20424,
#     37,
#     307,
#     257,
#     777,
#     4706,
#     1422,
#     3360,
#     295,
#     264,
#     2237,
#     1825,
#     370,
#     321,
#     434,
#     1417,
#     257,
#     2593,
#     300,
#     5497,
#     2331,
#     8319,
#     420,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.19719823201497397,
#    'compression_ratio': 1.6280701754385964,
#    'no_speech_prob': 0.006479488220065832},
#   {'id': 2,
#    'seek': 0,
#    'start': 12.0,
#    'end': 17.76,
#    'text': " 250 dollars and it's actually a little bit crazy what these guys have just pulled off for that price.",
#    'tokens': [50964,
#     11650,
#     3808,
#     293,
#     309,
#     311,
#     767,
#     257,
#     707,
#     857,
#     3219,
#     437,
#     613,
#     1074,
#     362,
#     445,
#     7373,
#     766,
#     337,
#     300,
#     3218,
#     13,
#     51252],
#    'temperature': 0.0,
#    'avg_logprob': -0.19719823201497397,
#    'compression_ratio': 1.6280701754385964,
#    'no_speech_prob': 0.006479488220065832},
#   {'id': 3,
#    'seek': 0,
#    'start': 17.76,
#    'end': 21.76,
#    'text': " I mean the first thing I'll notice is this doesn't feel like just a single product launch.",
#    'tokens': [51252,
#     286,
#     914,
#     264,
#     700,
#     551,
#     286,
#     603,
#     3449,
#     307,
#     341,
#     1177,
#     380,
#     841,
#     411,
#     445,
#     257,
#     2167,
#     1674,
#     4025,
#     13,
#     51452],
#    'temperature': 0.0,
#    'avg_logprob': -0.19719823201497397,
#    'compression_ratio': 1.6280701754385964,
#    'no_speech_prob': 0.006479488220065832},
#   {'id': 4,
#    'seek': 0,
#    'start': 21.76,
#    'end': 25.28,
#    'text': " This is an entire ecosystem and it's really fascinating one.",
#    'tokens': [51452,
#     639,
#     307,
#     364,
#     2302,
#     11311,
#     293,
#     309,
#     311,
#     534,
#     10343,
#     472,
#     13,
#     51628],
#    'temperature': 0.0,
#    'avg_logprob': -0.19719823201497397,
#    'compression_ratio': 1.6280701754385964,
#    'no_speech_prob': 0.006479488220065832},
#   {'id': 5,
#    'seek': 2528,
#    'start': 25.28,
#    'end': 29.36,
#    'text': " So let's get the phone out first. There's a Lanyard which is not something you tend to see",
#    'tokens': [50364,
#     407,
#     718,
#     311,
#     483,
#     264,
#     2593,
#     484,
#     700,
#     13,
#     821,
#     311,
#     257,
#     441,
#     1325,
#     515,
#     597,
#     307,
#     406,
#     746,
#     291,
#     3928,
#     281,
#     536,
#     50568],
#    'temperature': 0.0,
#    'avg_logprob': -0.18846354765050552,
#    'compression_ratio': 1.6901408450704225,
#    'no_speech_prob': 0.004903613589704037},
#   {'id': 6,
#    'seek': 2528,
#    'start': 29.36,
#    'end': 36.8,
#    'text': " launch with a phone. One case two cases no three cases a card wallet I guess that's for the back of the",
#    'tokens': [50568,
#     4025,
#     365,
#     257,
#     2593,
#     13,
#     1485,
#     1389,
#     732,
#     3331,
#     572,
#     1045,
#     3331,
#     257,
#     2920,
#     16599,
#     286,
#     2041,
#     300,
#     311,
#     337,
#     264,
#     646,
#     295,
#     264,
#     50940],
#    'temperature': 0.0,
#    'avg_logprob': -0.18846354765050552,
#    'compression_ratio': 1.6901408450704225,
#    'no_speech_prob': 0.004903613589704037},
#   {'id': 7,
#    'seek': 2528,
#    'start': 36.8,
#    'end': 43.84,
#    'text': " phone. There's a stand the Buds Pro 2 and then the watch Pro 2. It all feels very new because",
#    'tokens': [50940,
#     2593,
#     13,
#     821,
#     311,
#     257,
#     1463,
#     264,
#     6384,
#     82,
#     1705,
#     568,
#     293,
#     550,
#     264,
#     1159,
#     1705,
#     568,
#     13,
#     467,
#     439,
#     3417,
#     588,
#     777,
#     570,
#     51292],
#    'temperature': 0.0,
#    'avg_logprob': -0.18846354765050552,
#    'compression_ratio': 1.6901408450704225,
#    'no_speech_prob': 0.004903613589704037},
#   {'id': 8,
#    'seek': 2528,
#    'start': 43.84,
#    'end': 49.040000000000006,
#    'text': " we've seen plenty of budget phones before but what you don't often get is a budget accessory ecosystem",
#    'tokens': [51292,
#     321,
#     600,
#     1612,
#     7140,
#     295,
#     4706,
#     10216,
#     949,
#     457,
#     437,
#     291,
#     500,
#     380,
#     2049,
#     483,
#     307,
#     257,
#     4706,
#     30617,
#     11311,
#     51552],
#    'temperature': 0.0,
#    'avg_logprob': -0.18846354765050552,
#    'compression_ratio': 1.6901408450704225,
#    'no_speech_prob': 0.004903613589704037},
#   {'id': 9,
#    'seek': 2528,
#    'start': 49.040000000000006,
#    'end': 54.0,
#    'text': ' like this all designed to work specifically around that budget phone as the centerpiece.',
#    'tokens': [51552,
#     411,
#     341,
#     439,
#     4761,
#     281,
#     589,
#     4682,
#     926,
#     300,
#     4706,
#     2593,
#     382,
#     264,
#     3056,
#     15281,
#     13,
#     51800],
#    'temperature': 0.0,
#    'avg_logprob': -0.18846354765050552,
#    'compression_ratio': 1.6901408450704225,
#    'no_speech_prob': 0.004903613589704037},
#   {'id': 10,
#    'seek': 5400,
#    'start': 54.0,
#    'end': 59.52,
#    'text': ' Everything has well on one hand a slightly cheap thin plastic key feel to it but then on the other',
#    'tokens': [50364,
#     5471,
#     575,
#     731,
#     322,
#     472,
#     1011,
#     257,
#     4748,
#     7084,
#     5862,
#     5900,
#     2141,
#     841,
#     281,
#     309,
#     457,
#     550,
#     322,
#     264,
#     661,
#     50640],
#    'temperature': 0.0,
#    'avg_logprob': -0.10774280911400205,
#    'compression_ratio': 1.7182662538699691,
#    'no_speech_prob': 0.000779125199187547},
#   {'id': 11,
#    'seek': 5400,
#    'start': 59.52,
#    'end': 64.24,
#    'text': " hand it's all really tastefully designed. It kind of feels like all of these products have had",
#    'tokens': [50640,
#     1011,
#     309,
#     311,
#     439,
#     534,
#     3939,
#     2277,
#     4761,
#     13,
#     467,
#     733,
#     295,
#     3417,
#     411,
#     439,
#     295,
#     613,
#     3383,
#     362,
#     632,
#     50876],
#    'temperature': 0.0,
#    'avg_logprob': -0.10774280911400205,
#    'compression_ratio': 1.7182662538699691,
#    'no_speech_prob': 0.000779125199187547},
#   {'id': 12,
#    'seek': 5400,
#    'start': 64.24,
#    'end': 69.6,
#    'text': ' high end thought and care put into them even if the physical materials and the finish are',
#    'tokens': [50876,
#     1090,
#     917,
#     1194,
#     293,
#     1127,
#     829,
#     666,
#     552,
#     754,
#     498,
#     264,
#     4001,
#     5319,
#     293,
#     264,
#     2413,
#     366,
#     51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.10774280911400205,
#    'compression_ratio': 1.7182662538699691,
#    'no_speech_prob': 0.000779125199187547},
#   {'id': 13,
#    'seek': 5400,
#    'start': 69.6,
#    'end': 74.16,
#    'text': " more basic. So like these are the CMF Buds 2 Pro and even though they're very light and",
#    'tokens': [51144,
#     544,
#     3875,
#     13,
#     407,
#     411,
#     613,
#     366,
#     264,
#     20424,
#     37,
#     6384,
#     82,
#     568,
#     1705,
#     293,
#     754,
#     1673,
#     436,
#     434,
#     588,
#     1442,
#     293,
#     51372],
#    'temperature': 0.0,
#    'avg_logprob': -0.10774280911400205,
#    'compression_ratio': 1.7182662538699691,
#    'no_speech_prob': 0.000779125199187547},
#   {'id': 14,
#    'seek': 5400,
#    'start': 74.16,
#    'end': 78.88,
#    'text': ' clearly not a luxury item they still feel sophisticated and intentional in their design.',
#    'tokens': [51372,
#     4448,
#     406,
#     257,
#     15558,
#     3174,
#     436,
#     920,
#     841,
#     16950,
#     293,
#     21935,
#     294,
#     641,
#     1715,
#     13,
#     51608],
#    'temperature': 0.0,
#    'avg_logprob': -0.10774280911400205,
#    'compression_ratio': 1.7182662538699691,
#    'no_speech_prob': 0.000779125199187547},
#   {'id': 15,
#    'seek': 5400,
#    'start': 78.88,
#    'end': 83.03999999999999,
#    'text': ' Not like a cheap version of something that the company would rather you buy and then the watch',
#    'tokens': [51608,
#     1726,
#     411,
#     257,
#     7084,
#     3037,
#     295,
#     746,
#     300,
#     264,
#     2237,
#     576,
#     2831,
#     291,
#     2256,
#     293,
#     550,
#     264,
#     1159,
#     51816],
#    'temperature': 0.0,
#    'avg_logprob': -0.10774280911400205,
#    'compression_ratio': 1.7182662538699691,
#    'no_speech_prob': 0.000779125199187547},
#   {'id': 16,
#    'seek': 8304,
#    'start': 83.68,
#    'end': 89.36000000000001,
#    'text': " Pro 2. Yeah it's slick clean. You never want to watch to go too crazy on design because",
#    'tokens': [50396,
#     1705,
#     568,
#     13,
#     865,
#     309,
#     311,
#     37406,
#     2541,
#     13,
#     509,
#     1128,
#     528,
#     281,
#     1159,
#     281,
#     352,
#     886,
#     3219,
#     322,
#     1715,
#     570,
#     50680],
#    'temperature': 0.0,
#    'avg_logprob': -0.1712904645685564,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.004899089690297842},
#   {'id': 17,
#    'seek': 8304,
#    'start': 89.36000000000001,
#    'end': 93.28,
#    'text': " then it won't match your outfits. So this feels like a pretty appropriate level to me.",
#    'tokens': [50680,
#     550,
#     309,
#     1582,
#     380,
#     2995,
#     428,
#     22331,
#     13,
#     407,
#     341,
#     3417,
#     411,
#     257,
#     1238,
#     6854,
#     1496,
#     281,
#     385,
#     13,
#     50876],
#    'temperature': 0.0,
#    'avg_logprob': -0.1712904645685564,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.004899089690297842},
#   {'id': 18,
#    'seek': 8304,
#    'start': 93.28,
#    'end': 97.2,
#    'text': " Right let's get into this phone it's a thin package so we all know what that means.",
#    'tokens': [50876,
#     1779,
#     718,
#     311,
#     483,
#     666,
#     341,
#     2593,
#     309,
#     311,
#     257,
#     5862,
#     7372,
#     370,
#     321,
#     439,
#     458,
#     437,
#     300,
#     1355,
#     13,
#     51072],
#    'temperature': 0.0,
#    'avg_logprob': -0.1712904645685564,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.004899089690297842},
#   {'id': 19,
#    'seek': 8304,
#    'start': 97.2,
#    'end': 102.56,
#    'text': ' Okay so the device is on top and below that is a generic white USB C to C cable which you should',
#    'tokens': [51072,
#     1033,
#     370,
#     264,
#     4302,
#     307,
#     322,
#     1192,
#     293,
#     2507,
#     300,
#     307,
#     257,
#     19577,
#     2418,
#     10109,
#     383,
#     281,
#     383,
#     8220,
#     597,
#     291,
#     820,
#     51340],
#    'temperature': 0.0,
#    'avg_logprob': -0.1712904645685564,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.004899089690297842},
#   {'id': 20,
#    'seek': 8304,
#    'start': 102.56,
#    'end': 107.76,
#    'text': ' be able to use to transfer everything from the old phone and then an orange sim ejector. Right',
#    'tokens': [51340,
#     312,
#     1075,
#     281,
#     764,
#     281,
#     5003,
#     1203,
#     490,
#     264,
#     1331,
#     2593,
#     293,
#     550,
#     364,
#     7671,
#     1034,
#     32520,
#     284,
#     13,
#     1779,
#     51600],
#    'temperature': 0.0,
#    'avg_logprob': -0.1712904645685564,
#    'compression_ratio': 1.618705035971223,
#    'no_speech_prob': 0.004899089690297842},
#   {'id': 21,
#    'seek': 10776,
#    'start': 107.76,
#    'end': 120.08000000000001,
#    'text': " heel time. And right off the bat it's pretty clear that this is not your normal phone and",
#    'tokens': [50364,
#     9430,
#     565,
#     13,
#     400,
#     558,
#     766,
#     264,
#     7362,
#     309,
#     311,
#     1238,
#     1850,
#     300,
#     341,
#     307,
#     406,
#     428,
#     2710,
#     2593,
#     293,
#     50980],
#    'temperature': 0.0,
#    'avg_logprob': -0.1431798209314761,
#    'compression_ratio': 1.6176470588235294,
#    'no_speech_prob': 0.0003199297934770584},
#   {'id': 22,
#    'seek': 10776,
#    'start': 120.08000000000001,
#    'end': 124.88000000000001,
#    'text': " it's not just that it looks different because you know these cases that I showed you. These are",
#    'tokens': [50980,
#     309,
#     311,
#     406,
#     445,
#     300,
#     309,
#     1542,
#     819,
#     570,
#     291,
#     458,
#     613,
#     3331,
#     300,
#     286,
#     4712,
#     291,
#     13,
#     1981,
#     366,
#     51220],
#    'temperature': 0.0,
#    'avg_logprob': -0.1431798209314761,
#    'compression_ratio': 1.6176470588235294,
#    'no_speech_prob': 0.0003199297934770584},
#   {'id': 23,
#    'seek': 10776,
#    'start': 124.88000000000001,
#    'end': 129.92000000000002,
#    'text': " actually back plates. So if you look inside the packaging they came in you'll see a bunch of other stuff",
#    'tokens': [51220,
#     767,
#     646,
#     14231,
#     13,
#     407,
#     498,
#     291,
#     574,
#     1854,
#     264,
#     16836,
#     436,
#     1361,
#     294,
#     291,
#     603,
#     536,
#     257,
#     3840,
#     295,
#     661,
#     1507,
#     51472],
#    'temperature': 0.0,
#    'avg_logprob': -0.1431798209314761,
#    'compression_ratio': 1.6176470588235294,
#    'no_speech_prob': 0.0003199297934770584},
#   {'id': 24,
#    'seek': 10776,
#    'start': 129.92000000000002,
#    'end': 135.68,
#    'text': ' like this tool which is both a sim ejector and a screwdriver that allows you to take off these',
#    'tokens': [51472,
#     411,
#     341,
#     2290,
#     597,
#     307,
#     1293,
#     257,
#     1034,
#     32520,
#     284,
#     293,
#     257,
#     27282,
#     300,
#     4045,
#     291,
#     281,
#     747,
#     766,
#     613,
#     51760],
#    'temperature': 0.0,
#    'avg_logprob': -0.1431798209314761,
#    'compression_ratio': 1.6176470588235294,
#    'no_speech_prob': 0.0003199297934770584},
#   {'id': 25,
#    'seek': 13568,
#    'start': 135.68,
#    'end': 141.20000000000002,
#    'text': " four screws on the back of your phone after which you unwind this circular piece and you're played",
#    'tokens': [50364,
#     1451,
#     13050,
#     322,
#     264,
#     646,
#     295,
#     428,
#     2593,
#     934,
#     597,
#     291,
#     517,
#     12199,
#     341,
#     16476,
#     2522,
#     293,
#     291,
#     434,
#     3737,
#     50640],
#    'temperature': 0.0,
#    'avg_logprob': -0.19109472177796444,
#    'compression_ratio': 1.686206896551724,
#    'no_speech_prob': 0.004904158413410187},
#   {'id': 26,
#    'seek': 13568,
#    'start': 142.0,
#    'end': 147.76000000000002,
#    'text': ' pops off and this is a pretty big deal for a number of reasons. One that repairing this phone is',
#    'tokens': [50680,
#     16795,
#     766,
#     293,
#     341,
#     307,
#     257,
#     1238,
#     955,
#     2028,
#     337,
#     257,
#     1230,
#     295,
#     4112,
#     13,
#     1485,
#     300,
#     46158,
#     341,
#     2593,
#     307,
#     50968],
#    'temperature': 0.0,
#    'avg_logprob': -0.19109472177796444,
#    'compression_ratio': 1.686206896551724,
#    'no_speech_prob': 0.004904158413410187},
#   {'id': 27,
#    'seek': 13568,
#    'start': 147.76000000000002,
#    'end': 152.88,
#    'text': " going to be a lot easier and I hope cheaper than almost any other phone but that part's not confirmed.",
#    'tokens': [50968,
#     516,
#     281,
#     312,
#     257,
#     688,
#     3571,
#     293,
#     286,
#     1454,
#     12284,
#     813,
#     1920,
#     604,
#     661,
#     2593,
#     457,
#     300,
#     644,
#     311,
#     406,
#     11341,
#     13,
#     51224],
#    'temperature': 0.0,
#    'avg_logprob': -0.19109472177796444,
#    'compression_ratio': 1.686206896551724,
#    'no_speech_prob': 0.004904158413410187},
#   {'id': 28,
#    'seek': 13568,
#    'start': 152.88,
#    'end': 158.96,
#    'text': " To that you don't need a case anymore you can actually use your phone naked, guilt-free knowing that",
#    'tokens': [51224,
#     1407,
#     300,
#     291,
#     500,
#     380,
#     643,
#     257,
#     1389,
#     3602,
#     291,
#     393,
#     767,
#     764,
#     428,
#     2593,
#     15791,
#     11,
#     20421,
#     12,
#     10792,
#     5276,
#     300,
#     51528],
#    'temperature': 0.0,
#    'avg_logprob': -0.19109472177796444,
#    'compression_ratio': 1.686206896551724,
#    'no_speech_prob': 0.004904158413410187},
#   {'id': 29,
#    'seek': 13568,
#    'start': 158.96,
#    'end': 163.92000000000002,
#    'text': " if you ever do do something stupid you can just swap the back plate out for, I'm not even",
#    'tokens': [51528,
#     498,
#     291,
#     1562,
#     360,
#     360,
#     746,
#     6631,
#     291,
#     393,
#     445,
#     18135,
#     264,
#     646,
#     5924,
#     484,
#     337,
#     11,
#     286,
#     478,
#     406,
#     754,
#     51776],
#    'temperature': 0.0,
#    'avg_logprob': -0.19109472177796444,
#    'compression_ratio': 1.686206896551724,
#    'no_speech_prob': 0.004904158413410187},
#   {'id': 30,
#    'seek': 16392,
#    'start': 163.92,
#    'end': 169.28,
#    'text': " that much money, 29 pounds is what they're charging for these kits including the tools. The third thing",
#    'tokens': [50364,
#     300,
#     709,
#     1460,
#     11,
#     9413,
#     8319,
#     307,
#     437,
#     436,
#     434,
#     11379,
#     337,
#     613,
#     22095,
#     3009,
#     264,
#     3873,
#     13,
#     440,
#     2636,
#     551,
#     50632],
#    'temperature': 0.0,
#    'avg_logprob': -0.1490823165230129,
#    'compression_ratio': 1.7067137809187278,
#    'no_speech_prob': 0.0019260011613368988},
#   {'id': 31,
#    'seek': 16392,
#    'start': 169.28,
#    'end': 174.48,
#    'text': ' is it means you can mix a match. So I really like this orange back. It swaps out the slightly',
#    'tokens': [50632,
#     307,
#     309,
#     1355,
#     291,
#     393,
#     2890,
#     257,
#     2995,
#     13,
#     407,
#     286,
#     534,
#     411,
#     341,
#     7671,
#     646,
#     13,
#     467,
#     1693,
#     2382,
#     484,
#     264,
#     4748,
#     50892],
#    'temperature': 0.0,
#    'avg_logprob': -0.1490823165230129,
#    'compression_ratio': 1.7067137809187278,
#    'no_speech_prob': 0.0019260011613368988},
#   {'id': 32,
#    'seek': 16392,
#    'start': 174.48,
#    'end': 180.16,
#    'text': ' cheap feeling very scratchable plastic for a more grippy, less scratchable vegan leather type',
#    'tokens': [50892,
#     7084,
#     2633,
#     588,
#     8459,
#     712,
#     5900,
#     337,
#     257,
#     544,
#     17865,
#     7966,
#     11,
#     1570,
#     8459,
#     712,
#     12824,
#     12821,
#     2010,
#     51176],
#    'temperature': 0.0,
#    'avg_logprob': -0.1490823165230129,
#    'compression_ratio': 1.7067137809187278,
#    'no_speech_prob': 0.0019260011613368988},
#   {'id': 33,
#    'seek': 16392,
#    'start': 180.16,
#    'end': 185.6,
#    'text': " finish and it's bright orange so let's put it on. But then I'm looking at the orange sim tray,",
#    'tokens': [51176,
#     2413,
#     293,
#     309,
#     311,
#     4730,
#     7671,
#     370,
#     718,
#     311,
#     829,
#     309,
#     322,
#     13,
#     583,
#     550,
#     286,
#     478,
#     1237,
#     412,
#     264,
#     7671,
#     1034,
#     16027,
#     11,
#     51448],
#    'temperature': 0.0,
#    'avg_logprob': -0.1490823165230129,
#    'compression_ratio': 1.7067137809187278,
#    'no_speech_prob': 0.0019260011613368988},
#   {'id': 34,
#    'seek': 16392,
#    'start': 185.6,
#    'end': 189.83999999999997,
#    'text': ' the orange circle screw thing and the silver screws that come with it and thinking silver screws',
#    'tokens': [51448,
#     264,
#     7671,
#     6329,
#     5630,
#     551,
#     293,
#     264,
#     8753,
#     13050,
#     300,
#     808,
#     365,
#     309,
#     293,
#     1953,
#     8753,
#     13050,
#     51660],
#    'temperature': 0.0,
#    'avg_logprob': -0.1490823165230129,
#    'compression_ratio': 1.7067137809187278,
#    'no_speech_prob': 0.0019260011613368988},
#   {'id': 35,
#    'seek': 18984,
#    'start': 189.84,
#    'end': 194.96,
#    'text': ' are pretty nice but for the other parts I think I prefer the black ones so I have just created my',
#    'tokens': [50364,
#     366,
#     1238,
#     1481,
#     457,
#     337,
#     264,
#     661,
#     3166,
#     286,
#     519,
#     286,
#     4382,
#     264,
#     2211,
#     2306,
#     370,
#     286,
#     362,
#     445,
#     2942,
#     452,
#     50620],
#    'temperature': 0.0,
#    'avg_logprob': -0.18207863517429518,
#    'compression_ratio': 1.7846715328467153,
#    'no_speech_prob': 0.0042632450349628925},
#   {'id': 36,
#    'seek': 18984,
#    'start': 194.96,
#    'end': 200.64000000000001,
#    'text': " own two-tone finish on my phone and that's actually sick but the best part of this is that nothing",
#    'tokens': [50620,
#     1065,
#     732,
#     12,
#     41656,
#     2413,
#     322,
#     452,
#     2593,
#     293,
#     300,
#     311,
#     767,
#     4998,
#     457,
#     264,
#     1151,
#     644,
#     295,
#     341,
#     307,
#     300,
#     1825,
#     50904],
#    'temperature': 0.0,
#    'avg_logprob': -0.18207863517429518,
#    'compression_ratio': 1.7846715328467153,
#    'no_speech_prob': 0.0042632450349628925},
#   {'id': 37,
#    'seek': 18984,
#    'start': 200.64000000000001,
#    'end': 206.32,
#    'text': ' has actually gone one step further to actually create an ecosystem around these weird screws and',
#    'tokens': [50904,
#     575,
#     767,
#     2780,
#     472,
#     1823,
#     3052,
#     281,
#     767,
#     1884,
#     364,
#     11311,
#     926,
#     613,
#     3657,
#     13050,
#     293,
#     51188],
#    'temperature': 0.0,
#    'avg_logprob': -0.18207863517429518,
#    'compression_ratio': 1.7846715328467153,
#    'no_speech_prob': 0.0042632450349628925},
#   {'id': 38,
#    'seek': 18984,
#    'start': 206.96,
#    'end': 212.16,
#    'text': " I don't even know what to call this. Now on this is the circle spinny thing. So if I want a phone",
#    'tokens': [51220,
#     286,
#     500,
#     380,
#     754,
#     458,
#     437,
#     281,
#     818,
#     341,
#     13,
#     823,
#     322,
#     341,
#     307,
#     264,
#     6329,
#     6060,
#     1634,
#     551,
#     13,
#     407,
#     498,
#     286,
#     528,
#     257,
#     2593,
#     51480],
#    'temperature': 0.0,
#    'avg_logprob': -0.18207863517429518,
#    'compression_ratio': 1.7846715328467153,
#    'no_speech_prob': 0.0042632450349628925},
#   {'id': 39,
#    'seek': 18984,
#    'start': 212.16,
#    'end': 216.96,
#    'text': ' stand for example unscrew your circle spinny thing and screw this down then and yeah the standard',
#    'tokens': [51480,
#     1463,
#     337,
#     1365,
#     42579,
#     428,
#     6329,
#     6060,
#     1634,
#     551,
#     293,
#     5630,
#     341,
#     760,
#     550,
#     293,
#     1338,
#     264,
#     3832,
#     51720],
#    'temperature': 0.0,
#    'avg_logprob': -0.18207863517429518,
#    'compression_ratio': 1.7846715328467153,
#    'no_speech_prob': 0.0042632450349628925},
#   {'id': 40,
#    'seek': 21696,
#    'start': 216.96,
#    'end': 221.92000000000002,
#    'text': " self isn't anything particularly special. It's not breaking new grounds in material science but",
#    'tokens': [50364,
#     2698,
#     1943,
#     380,
#     1340,
#     4098,
#     2121,
#     13,
#     467,
#     311,
#     406,
#     7697,
#     777,
#     19196,
#     294,
#     2527,
#     3497,
#     457,
#     50612],
#    'temperature': 0.0,
#    'avg_logprob': -0.1356690154885346,
#    'compression_ratio': 1.7545787545787546,
#    'no_speech_prob': 0.006901981309056282},
#   {'id': 41,
#    'seek': 21696,
#    'start': 221.92000000000002,
#    'end': 226.48000000000002,
#    'text': ' if you decide that you want a phone stand then what better way to have a phone stand',
#    'tokens': [50612,
#     498,
#     291,
#     4536,
#     300,
#     291,
#     528,
#     257,
#     2593,
#     1463,
#     550,
#     437,
#     1101,
#     636,
#     281,
#     362,
#     257,
#     2593,
#     1463,
#     50840],
#    'temperature': 0.0,
#    'avg_logprob': -0.1356690154885346,
#    'compression_ratio': 1.7545787545787546,
#    'no_speech_prob': 0.006901981309056282},
#   {'id': 42,
#    'seek': 21696,
#    'start': 226.48000000000002,
#    'end': 231.44,
#    'text': " that doesn't need you to apply a sticky pad onto your case but instead physically screws into your",
#    'tokens': [50840,
#     300,
#     1177,
#     380,
#     643,
#     291,
#     281,
#     3079,
#     257,
#     14470,
#     6887,
#     3911,
#     428,
#     1389,
#     457,
#     2602,
#     9762,
#     13050,
#     666,
#     428,
#     51088],
#    'temperature': 0.0,
#    'avg_logprob': -0.1356690154885346,
#    'compression_ratio': 1.7545787545787546,
#    'no_speech_prob': 0.006901981309056282},
#   {'id': 43,
#    'seek': 21696,
#    'start': 231.44,
#    'end': 236.8,
#    'text': ' device itself. It feels way more secure and also way more intentional like your stand was designed',
#    'tokens': [51088,
#     4302,
#     2564,
#     13,
#     467,
#     3417,
#     636,
#     544,
#     7144,
#     293,
#     611,
#     636,
#     544,
#     21935,
#     411,
#     428,
#     1463,
#     390,
#     4761,
#     51356],
#    'temperature': 0.0,
#    'avg_logprob': -0.1356690154885346,
#    'compression_ratio': 1.7545787545787546,
#    'no_speech_prob': 0.006901981309056282},
#   {'id': 44,
#    'seek': 21696,
#    'start': 236.8,
#    'end': 242.16,
#    'text': " specifically for your phone. You want a lanyard same thing and I feel very confident that it's going",
#    'tokens': [51356,
#     4682,
#     337,
#     428,
#     2593,
#     13,
#     509,
#     528,
#     257,
#     287,
#     1325,
#     515,
#     912,
#     551,
#     293,
#     286,
#     841,
#     588,
#     6679,
#     300,
#     309,
#     311,
#     516,
#     51624],
#    'temperature': 0.0,
#    'avg_logprob': -0.1356690154885346,
#    'compression_ratio': 1.7545787545787546,
#    'no_speech_prob': 0.006901981309056282},
#   {'id': 45,
#    'seek': 24216,
#    'start': 242.16,
#    'end': 248.4,
#    'text': " to support the phone because it's bolted to it or like there's no magsafe wireless charging baked",
#    'tokens': [50364,
#     281,
#     1406,
#     264,
#     2593,
#     570,
#     309,
#     311,
#     13436,
#     292,
#     281,
#     309,
#     420,
#     411,
#     456,
#     311,
#     572,
#     2258,
#     5790,
#     2106,
#     14720,
#     11379,
#     19453,
#     50676],
#    'temperature': 0.0,
#    'avg_logprob': -0.12433079310825892,
#    'compression_ratio': 1.7380073800738007,
#    'no_speech_prob': 0.011151163838803768},
#   {'id': 46,
#    'seek': 24216,
#    'start': 248.4,
#    'end': 252.24,
#    'text': " into this phone right you can't just slap one of those Apple wallets onto the back of this and",
#    'tokens': [50676,
#     666,
#     341,
#     2593,
#     558,
#     291,
#     393,
#     380,
#     445,
#     21075,
#     472,
#     295,
#     729,
#     6373,
#     2929,
#     1385,
#     3911,
#     264,
#     646,
#     295,
#     341,
#     293,
#     50868],
#    'temperature': 0.0,
#    'avg_logprob': -0.12433079310825892,
#    'compression_ratio': 1.7380073800738007,
#    'no_speech_prob': 0.011151163838803768},
#   {'id': 47,
#    'seek': 24216,
#    'start': 252.24,
#    'end': 259.6,
#    'text': " expect it to hold but screw this CMF wallet enclosure in like this that's very secure and now",
#    'tokens': [50868,
#     2066,
#     309,
#     281,
#     1797,
#     457,
#     5630,
#     341,
#     20424,
#     37,
#     16599,
#     34093,
#     294,
#     411,
#     341,
#     300,
#     311,
#     588,
#     7144,
#     293,
#     586,
#     51236],
#    'temperature': 0.0,
#    'avg_logprob': -0.12433079310825892,
#    'compression_ratio': 1.7380073800738007,
#    'no_speech_prob': 0.011151163838803768},
#   {'id': 48,
#    'seek': 24216,
#    'start': 259.6,
#    'end': 264.24,
#    'text': ' you have your magnet to be able to attach your wallet on top of and this thing can hold like',
#    'tokens': [51236,
#     291,
#     362,
#     428,
#     15211,
#     281,
#     312,
#     1075,
#     281,
#     5085,
#     428,
#     16599,
#     322,
#     1192,
#     295,
#     293,
#     341,
#     551,
#     393,
#     1797,
#     411,
#     51468],
#    'temperature': 0.0,
#    'avg_logprob': -0.12433079310825892,
#    'compression_ratio': 1.7380073800738007,
#    'no_speech_prob': 0.011151163838803768},
#   {'id': 49,
#    'seek': 24216,
#    'start': 264.24,
#    'end': 269.12,
#    'text': ' three cards this whole thing reminds me very much of a mentality that I discovered in India',
#    'tokens': [51468,
#     1045,
#     5632,
#     341,
#     1379,
#     551,
#     12025,
#     385,
#     588,
#     709,
#     295,
#     257,
#     21976,
#     300,
#     286,
#     6941,
#     294,
#     5282,
#     51712],
#    'temperature': 0.0,
#    'avg_logprob': -0.12433079310825892,
#    'compression_ratio': 1.7380073800738007,
#    'no_speech_prob': 0.011151163838803768},
#   {'id': 50,
#    'seek': 26912,
#    'start': 269.12,
#    'end': 274.64,
#    'text': " it's called jagad it means uh frugal innovation inventive ways to use what you have to achieve",
#    'tokens': [50364,
#     309,
#     311,
#     1219,
#     361,
#     559,
#     345,
#     309,
#     1355,
#     2232,
#     431,
#     17812,
#     8504,
#     7962,
#     488,
#     2098,
#     281,
#     764,
#     437,
#     291,
#     362,
#     281,
#     4584,
#     50640],
#    'temperature': 0.0,
#    'avg_logprob': -0.13525169035967657,
#    'compression_ratio': 1.7841726618705036,
#    'no_speech_prob': 0.002251110738143325},
#   {'id': 51,
#    'seek': 26912,
#    'start': 274.64,
#    'end': 279.6,
#    'text': ' things that would normally require more resources because just by properly thinking this through before',
#    'tokens': [50640,
#     721,
#     300,
#     576,
#     5646,
#     3651,
#     544,
#     3593,
#     570,
#     445,
#     538,
#     6108,
#     1953,
#     341,
#     807,
#     949,
#     50888],
#    'temperature': 0.0,
#    'avg_logprob': -0.13525169035967657,
#    'compression_ratio': 1.7841726618705036,
#    'no_speech_prob': 0.002251110738143325},
#   {'id': 52,
#    'seek': 26912,
#    'start': 279.6,
#    'end': 284.96,
#    'text': ' building it this company has genuinely achieved a really high level of functionality without making',
#    'tokens': [50888,
#     2390,
#     309,
#     341,
#     2237,
#     575,
#     17839,
#     11042,
#     257,
#     534,
#     1090,
#     1496,
#     295,
#     14980,
#     1553,
#     1455,
#     51156],
#    'temperature': 0.0,
#    'avg_logprob': -0.13525169035967657,
#    'compression_ratio': 1.7841726618705036,
#    'no_speech_prob': 0.002251110738143325},
#   {'id': 53,
#    'seek': 26912,
#    'start': 284.96,
#    'end': 290.08,
#    'text': " it cost them any more to build this thing you're actually getting something here but you can't get",
#    'tokens': [51156,
#     309,
#     2063,
#     552,
#     604,
#     544,
#     281,
#     1322,
#     341,
#     551,
#     291,
#     434,
#     767,
#     1242,
#     746,
#     510,
#     457,
#     291,
#     393,
#     380,
#     483,
#     51412],
#    'temperature': 0.0,
#    'avg_logprob': -0.13525169035967657,
#    'compression_ratio': 1.7841726618705036,
#    'no_speech_prob': 0.002251110738143325},
#   {'id': 54,
#    'seek': 26912,
#    'start': 290.08,
#    'end': 294.72,
#    'text': ' just by paying through the nose for a higher end device like nothing has managed to make something',
#    'tokens': [51412,
#     445,
#     538,
#     6229,
#     807,
#     264,
#     6690,
#     337,
#     257,
#     2946,
#     917,
#     4302,
#     411,
#     1825,
#     575,
#     6453,
#     281,
#     652,
#     746,
#     51644],
#    'temperature': 0.0,
#    'avg_logprob': -0.13525169035967657,
#    'compression_ratio': 1.7841726618705036,
#    'no_speech_prob': 0.002251110738143325},
#   {'id': 55,
#    'seek': 29472,
#    'start': 294.72,
#    'end': 302.96000000000004,
#    'text': ' that gives their $250 phone a tangible leg up over my $1200 phone and that is absolutely amazing',
#    'tokens': [50364,
#     300,
#     2709,
#     641,
#     1848,
#     23538,
#     2593,
#     257,
#     27094,
#     1676,
#     493,
#     670,
#     452,
#     1848,
#     4762,
#     628,
#     2593,
#     293,
#     300,
#     307,
#     3122,
#     2243,
#     50776],
#    'temperature': 0.0,
#    'avg_logprob': -0.12165691655710204,
#    'compression_ratio': 1.6723549488054608,
#    'no_speech_prob': 0.009854220785200596},
#   {'id': 56,
#    'seek': 29472,
#    'start': 302.96000000000004,
#    'end': 307.44000000000005,
#    'text': " I'm mind this kind of wearing other possibilities like I'm just thinking as an example what if you",
#    'tokens': [50776,
#     286,
#     478,
#     1575,
#     341,
#     733,
#     295,
#     4769,
#     661,
#     12178,
#     411,
#     286,
#     478,
#     445,
#     1953,
#     382,
#     364,
#     1365,
#     437,
#     498,
#     291,
#     51000],
#    'temperature': 0.0,
#    'avg_logprob': -0.12165691655710204,
#    'compression_ratio': 1.6723549488054608,
#    'no_speech_prob': 0.009854220785200596},
#   {'id': 57,
#    'seek': 29472,
#    'start': 307.44000000000005,
#    'end': 313.28000000000003,
#    'text': ' use this screw and this screw to add a permanent lens attachment to your cameras you know instead',
#    'tokens': [51000,
#     764,
#     341,
#     5630,
#     293,
#     341,
#     5630,
#     281,
#     909,
#     257,
#     10996,
#     6765,
#     19431,
#     281,
#     428,
#     8622,
#     291,
#     458,
#     2602,
#     51292],
#    'temperature': 0.0,
#    'avg_logprob': -0.12165691655710204,
#    'compression_ratio': 1.6723549488054608,
#    'no_speech_prob': 0.009854220785200596},
#   {'id': 58,
#    'seek': 29472,
#    'start': 313.28000000000003,
#    'end': 317.84000000000003,
#    'text': ' of those ones that you have to clip on and anything more than a light breeze will remove for you',
#    'tokens': [51292,
#     295,
#     729,
#     2306,
#     300,
#     291,
#     362,
#     281,
#     7353,
#     322,
#     293,
#     1340,
#     544,
#     813,
#     257,
#     1442,
#     24532,
#     486,
#     4159,
#     337,
#     291,
#     51520],
#    'temperature': 0.0,
#    'avg_logprob': -0.12165691655710204,
#    'compression_ratio': 1.6723549488054608,
#    'no_speech_prob': 0.009854220785200596},
#   {'id': 59,
#    'seek': 29472,
#    'start': 317.84000000000003,
#    'end': 321.92,
#    'text': ' now I would personally be a little bit worried about things getting inside they have managed to get',
#    'tokens': [51520,
#     586,
#     286,
#     576,
#     5665,
#     312,
#     257,
#     707,
#     857,
#     5804,
#     466,
#     721,
#     1242,
#     1854,
#     436,
#     362,
#     6453,
#     281,
#     483,
#     51724],
#    'temperature': 0.0,
#    'avg_logprob': -0.12165691655710204,
#    'compression_ratio': 1.6723549488054608,
#    'no_speech_prob': 0.009854220785200596},
#   {'id': 60,
#    'seek': 32192,
#    'start': 321.92,
#    'end': 327.44,
#    'text': ' an IPX true rating which is basically very minor water protection and nothing for dust and I think',
#    'tokens': [50364,
#     364,
#     8671,
#     55,
#     2074,
#     10990,
#     597,
#     307,
#     1936,
#     588,
#     6696,
#     1281,
#     6334,
#     293,
#     1825,
#     337,
#     8634,
#     293,
#     286,
#     519,
#     50640],
#    'temperature': 0.0,
#    'avg_logprob': -0.12234832193249855,
#    'compression_ratio': 1.7102473498233215,
#    'no_speech_prob': 0.01910318247973919},
#   {'id': 61,
#    'seek': 32192,
#    'start': 327.44,
#    'end': 331.76,
#    'text': " it's somewhat telling that that's the max rating they could get because yeah anything designed to",
#    'tokens': [50640,
#     309,
#     311,
#     8344,
#     3585,
#     300,
#     300,
#     311,
#     264,
#     11469,
#     10990,
#     436,
#     727,
#     483,
#     570,
#     1338,
#     1340,
#     4761,
#     281,
#     50856],
#    'temperature': 0.0,
#    'avg_logprob': -0.12234832193249855,
#    'compression_ratio': 1.7102473498233215,
#    'no_speech_prob': 0.01910318247973919},
#   {'id': 62,
#    'seek': 32192,
#    'start': 331.76,
#    'end': 337.36,
#    'text': ' be taken apart this easily is obviously not particularly well sealed and also as cool as the',
#    'tokens': [50856,
#     312,
#     2726,
#     4936,
#     341,
#     3612,
#     307,
#     2745,
#     406,
#     4098,
#     731,
#     21514,
#     293,
#     611,
#     382,
#     1627,
#     382,
#     264,
#     51136],
#    'temperature': 0.0,
#    'avg_logprob': -0.12234832193249855,
#    'compression_ratio': 1.7102473498233215,
#    'no_speech_prob': 0.01910318247973919},
#   {'id': 63,
#    'seek': 32192,
#    'start': 337.36,
#    'end': 342.48,
#    'text': ' circles of anything is I do find it a little bit uncomfortable just because it sticks out but let me',
#    'tokens': [51136,
#     13040,
#     295,
#     1340,
#     307,
#     286,
#     360,
#     915,
#     309,
#     257,
#     707,
#     857,
#     10532,
#     445,
#     570,
#     309,
#     12518,
#     484,
#     457,
#     718,
#     385,
#     51392],
#    'temperature': 0.0,
#    'avg_logprob': -0.12234832193249855,
#    'compression_ratio': 1.7102473498233215,
#    'no_speech_prob': 0.01910318247973919},
#   {'id': 64,
#    'seek': 32192,
#    'start': 342.48,
#    'end': 348.0,
#    'text': " be very clear all in all for the price this is one of the best designed phones I've ever seen",
#    'tokens': [51392,
#     312,
#     588,
#     1850,
#     439,
#     294,
#     439,
#     337,
#     264,
#     3218,
#     341,
#     307,
#     472,
#     295,
#     264,
#     1151,
#     4761,
#     10216,
#     286,
#     600,
#     1562,
#     1612,
#     51668],
#    'temperature': 0.0,
#    'avg_logprob': -0.12234832193249855,
#    'compression_ratio': 1.7102473498233215,
#    'no_speech_prob': 0.01910318247973919},
#   {'id': 65,
#    'seek': 34800,
#    'start': 348.0,
#    'end': 353.52,
#    'text': " which I'm only half surprised by because the entire name of this sub brand CMF very literally stands",
#    'tokens': [50364,
#     597,
#     286,
#     478,
#     787,
#     1922,
#     6100,
#     538,
#     570,
#     264,
#     2302,
#     1315,
#     295,
#     341,
#     1422,
#     3360,
#     20424,
#     37,
#     588,
#     3736,
#     7382,
#     50640],
#    'temperature': 0.0,
#    'avg_logprob': -0.14523858422631616,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.002250572433695197},
#   {'id': 66,
#    'seek': 34800,
#    'start': 353.52,
#    'end': 358.48,
#    'text': " for colors materials and finish it's actually the rest of the phone that surprised me more",
#    'tokens': [50640,
#     337,
#     4577,
#     5319,
#     293,
#     2413,
#     309,
#     311,
#     767,
#     264,
#     1472,
#     295,
#     264,
#     2593,
#     300,
#     6100,
#     385,
#     544,
#     50888],
#    'temperature': 0.0,
#    'avg_logprob': -0.14523858422631616,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.002250572433695197},
#   {'id': 67,
#    'seek': 34800,
#    'start': 358.48,
#    'end': 363.84,
#    'text': " so let's talk about it if you're winning with design at $250 then where are you losing",
#    'tokens': [50888,
#     370,
#     718,
#     311,
#     751,
#     466,
#     309,
#     498,
#     291,
#     434,
#     8224,
#     365,
#     1715,
#     412,
#     1848,
#     23538,
#     550,
#     689,
#     366,
#     291,
#     7027,
#     51156],
#    'temperature': 0.0,
#    'avg_logprob': -0.14523858422631616,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.002250572433695197},
#   {'id': 68,
#    'seek': 34800,
#    'start': 363.84,
#    'end': 369.84,
#    'text': " well it's not the screen this is a 120 Hertz adaptive ammo led full HD plus display it's very",
#    'tokens': [51156,
#     731,
#     309,
#     311,
#     406,
#     264,
#     2568,
#     341,
#     307,
#     257,
#     10411,
#     46910,
#     27912,
#     27340,
#     4684,
#     1577,
#     12149,
#     1804,
#     4674,
#     309,
#     311,
#     588,
#     51456],
#    'temperature': 0.0,
#    'avg_logprob': -0.14523858422631616,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.002250572433695197},
#   {'id': 69,
#    'seek': 34800,
#    'start': 369.84,
#    'end': 374.88,
#    'text': " smooth it's sharp it's punchy this thing can display HDR 10 plus content which is a luxury that",
#    'tokens': [51456,
#     5508,
#     309,
#     311,
#     8199,
#     309,
#     311,
#     8135,
#     88,
#     341,
#     551,
#     393,
#     4674,
#     29650,
#     1266,
#     1804,
#     2701,
#     597,
#     307,
#     257,
#     15558,
#     300,
#     51708],
#    'temperature': 0.0,
#    'avg_logprob': -0.14523858422631616,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.002250572433695197},
#   {'id': 70,
#    'seek': 37488,
#    'start': 374.88,
#    'end': 379.68,
#    'text': " you could only get by paying over a thousand dollars like literally two years ago they've pre-installed",
#    'tokens': [50364,
#     291,
#     727,
#     787,
#     483,
#     538,
#     6229,
#     670,
#     257,
#     4714,
#     3808,
#     411,
#     3736,
#     732,
#     924,
#     2057,
#     436,
#     600,
#     659,
#     12,
#     13911,
#     8907,
#     50604],
#    'temperature': 0.0,
#    'avg_logprob': -0.14012136913481213,
#    'compression_ratio': 1.7227138643067847,
#    'no_speech_prob': 0.003221141640096903},
#   {'id': 71,
#    'seek': 37488,
#    'start': 379.68,
#    'end': 384.48,
#    'text': ' a screen protector which I always rate and this right here is an in-display optical fingerprint scanner',
#    'tokens': [50604,
#     257,
#     2568,
#     34986,
#     597,
#     286,
#     1009,
#     3314,
#     293,
#     341,
#     558,
#     510,
#     307,
#     364,
#     294,
#     12,
#     35238,
#     20674,
#     30715,
#     30211,
#     50844],
#    'temperature': 0.0,
#    'avg_logprob': -0.14012136913481213,
#    'compression_ratio': 1.7227138643067847,
#    'no_speech_prob': 0.003221141640096903},
#   {'id': 72,
#    'seek': 37488,
#    'start': 384.48,
#    'end': 389.76,
#    'text': " which is well it's fine it works even the brightness which is one of the first things to go is",
#    'tokens': [50844,
#     597,
#     307,
#     731,
#     309,
#     311,
#     2489,
#     309,
#     1985,
#     754,
#     264,
#     21367,
#     597,
#     307,
#     472,
#     295,
#     264,
#     700,
#     721,
#     281,
#     352,
#     307,
#     51108],
#    'temperature': 0.0,
#    'avg_logprob': -0.14012136913481213,
#    'compression_ratio': 1.7227138643067847,
#    'no_speech_prob': 0.003221141640096903},
#   {'id': 73,
#    'seek': 37488,
#    'start': 389.76,
#    'end': 393.92,
#    'text': " actually pretty good the company's advertising a 2000 net peak brightness but you don't",
#    'tokens': [51108,
#     767,
#     1238,
#     665,
#     264,
#     2237,
#     311,
#     13097,
#     257,
#     8132,
#     2533,
#     10651,
#     21367,
#     457,
#     291,
#     500,
#     380,
#     51316],
#    'temperature': 0.0,
#    'avg_logprob': -0.14012136913481213,
#    'compression_ratio': 1.7227138643067847,
#    'no_speech_prob': 0.003221141640096903},
#   {'id': 74,
#    'seek': 37488,
#    'start': 393.92,
#    'end': 397.92,
#    'text': ' need to achieve that in very very specific situations more typically this thing can go up to a',
#    'tokens': [51316,
#     643,
#     281,
#     4584,
#     300,
#     294,
#     588,
#     588,
#     2685,
#     6851,
#     544,
#     5850,
#     341,
#     551,
#     393,
#     352,
#     493,
#     281,
#     257,
#     51516],
#    'temperature': 0.0,
#    'avg_logprob': -0.14012136913481213,
#    'compression_ratio': 1.7227138643067847,
#    'no_speech_prob': 0.003221141640096903},
#   {'id': 75,
#    'seek': 37488,
#    'start': 397.92,
#    'end': 403.76,
#    'text': ' max of 700 nets in normal brightness and then 1200 nets in ultra bright outdoor environments which',
#    'tokens': [51516,
#     11469,
#     295,
#     15204,
#     36170,
#     294,
#     2710,
#     21367,
#     293,
#     550,
#     29139,
#     36170,
#     294,
#     14808,
#     4730,
#     15942,
#     12388,
#     597,
#     51808],
#    'temperature': 0.0,
#    'avg_logprob': -0.14012136913481213,
#    'compression_ratio': 1.7227138643067847,
#    'no_speech_prob': 0.003221141640096903},
#   {'id': 76,
#    'seek': 40376,
#    'start': 403.76,
#    'end': 408.32,
#    'text': ' means that in the absolute worst worst case scenarios you might have to squint a little bit but',
#    'tokens': [50364,
#     1355,
#     300,
#     294,
#     264,
#     8236,
#     5855,
#     5855,
#     1389,
#     15077,
#     291,
#     1062,
#     362,
#     281,
#     2339,
#     686,
#     257,
#     707,
#     857,
#     457,
#     50592],
#    'temperature': 0.0,
#    'avg_logprob': -0.12839990150271438,
#    'compression_ratio': 1.7259475218658893,
#    'no_speech_prob': 0.001673106336966157},
#   {'id': 77,
#    'seek': 40376,
#    'start': 408.32,
#    'end': 412.4,
#    'text': " you'll pretty much never struggle to see it the only thing I would complain about and I'm being",
#    'tokens': [50592,
#     291,
#     603,
#     1238,
#     709,
#     1128,
#     7799,
#     281,
#     536,
#     309,
#     264,
#     787,
#     551,
#     286,
#     576,
#     11024,
#     466,
#     293,
#     286,
#     478,
#     885,
#     50796],
#    'temperature': 0.0,
#    'avg_logprob': -0.12839990150271438,
#    'compression_ratio': 1.7259475218658893,
#    'no_speech_prob': 0.001673106336966157},
#   {'id': 78,
#    'seek': 40376,
#    'start': 412.4,
#    'end': 417.12,
#    'text': ' quite nitpicky here but the bottom bezel is slightly thicker than the other bezels and this is',
#    'tokens': [50796,
#     1596,
#     10900,
#     79,
#     20539,
#     510,
#     457,
#     264,
#     2767,
#     37179,
#     307,
#     4748,
#     18142,
#     813,
#     264,
#     661,
#     10782,
#     1625,
#     293,
#     341,
#     307,
#     51032],
#    'temperature': 0.0,
#    'avg_logprob': -0.12839990150271438,
#    'compression_ratio': 1.7259475218658893,
#    'no_speech_prob': 0.001673106336966157},
#   {'id': 79,
#    'seek': 40376,
#    'start': 417.12,
#    'end': 422.0,
#    'text': ' particularly interesting because I remember having a conversation with Carl Pay the CEO when he launched',
#    'tokens': [51032,
#     4098,
#     1880,
#     570,
#     286,
#     1604,
#     1419,
#     257,
#     3761,
#     365,
#     14256,
#     11431,
#     264,
#     9282,
#     562,
# ...
#    'tokens': [51020,
#     9594,
#     9942,
#     291,
#     362,
#     7140,
#     295,
#     1808,
#     281,
#     8863,
#     294,
#     3052,
#     293,
#     436,
#     486,
#     920,
#     574,
#     8199,
#     264,
#     4874,
#     51268],
#    'temperature': 0.0,
#    'avg_logprob': -0.10588294982910157,
#    'compression_ratio': 1.7901234567901234,
#    'no_speech_prob': 0.0062791733071208},
#   {'id': 142,
#    'seek': 72264,
#    'start': 740.72,
#    'end': 746.08,
#    'text': ' aperture and decent sensor size gets you some nice foreground background separation and mostly',
#    'tokens': [51268,
#     29848,
#     293,
#     8681,
#     10200,
#     2744,
#     2170,
#     291,
#     512,
#     1481,
#     32058,
#     3678,
#     14634,
#     293,
#     5240,
#     51536],
#    'temperature': 0.0,
#    'avg_logprob': -0.10588294982910157,
#    'compression_ratio': 1.7901234567901234,
#    'no_speech_prob': 0.0062791733071208},
#   {'id': 143,
#    'seek': 72264,
#    'start': 746.08,
#    'end': 751.52,
#    'text': " flawless high dynamic range I say mostly just because it's absolutely spot on for big scenes where there's",
#    'tokens': [51536,
#     45693,
#     1090,
#     8546,
#     3613,
#     286,
#     584,
#     5240,
#     445,
#     570,
#     309,
#     311,
#     3122,
#     4008,
#     322,
#     337,
#     955,
#     8026,
#     689,
#     456,
#     311,
#     51808],
#    'temperature': 0.0,
#    'avg_logprob': -0.10588294982910157,
#    'compression_ratio': 1.7901234567901234,
#    'no_speech_prob': 0.0062791733071208},
#   {'id': 144,
#    'seek': 75152,
#    'start': 751.52,
#    'end': 756.64,
#    'text': ' an overexposed sky but it often misses the small things like a bright light bulb in your shop',
#    'tokens': [50364,
#     364,
#     38657,
#     87,
#     79,
#     1744,
#     5443,
#     457,
#     309,
#     2049,
#     29394,
#     264,
#     1359,
#     721,
#     411,
#     257,
#     4730,
#     1442,
#     21122,
#     294,
#     428,
#     3945,
#     50620],
#    'temperature': 0.0,
#    'avg_logprob': -0.1437590843023256,
#    'compression_ratio': 1.900662251655629,
#    'no_speech_prob': 0.010977796278893948},
#   {'id': 145,
#    'seek': 75152,
#    'start': 756.64,
#    'end': 761.84,
#    'text': ' that needs controlling and you know what the video has no right to look this decent the phone',
#    'tokens': [50620,
#     300,
#     2203,
#     14905,
#     293,
#     291,
#     458,
#     437,
#     264,
#     960,
#     575,
#     572,
#     558,
#     281,
#     574,
#     341,
#     8681,
#     264,
#     2593,
#     50880],
#    'temperature': 0.0,
#    'avg_logprob': -0.1437590843023256,
#    'compression_ratio': 1.900662251655629,
#    'no_speech_prob': 0.010977796278893948},
#   {'id': 146,
#    'seek': 75152,
#    'start': 761.84,
#    'end': 766.88,
#    'text': " shoots 4k footage at 30 frames per second and it doesn't feel particularly noisy which you might",
#    'tokens': [50880,
#     20704,
#     1017,
#     74,
#     9556,
#     412,
#     2217,
#     12083,
#     680,
#     1150,
#     293,
#     309,
#     1177,
#     380,
#     841,
#     4098,
#     24518,
#     597,
#     291,
#     1062,
#     51132],
#    'temperature': 0.0,
#    'avg_logprob': -0.1437590843023256,
#    'compression_ratio': 1.900662251655629,
#    'no_speech_prob': 0.010977796278893948},
#   {'id': 147,
#    'seek': 75152,
#    'start': 766.88,
#    'end': 771.12,
#    'text': " expect to do since this phone's chip doesn't have the best image signal processor it doesn't",
#    'tokens': [51132,
#     2066,
#     281,
#     360,
#     1670,
#     341,
#     2593,
#     311,
#     11409,
#     1177,
#     380,
#     362,
#     264,
#     1151,
#     3256,
#     6358,
#     15321,
#     309,
#     1177,
#     380,
#     51344],
#    'temperature': 0.0,
#    'avg_logprob': -0.1437590843023256,
#    'compression_ratio': 1.900662251655629,
#    'no_speech_prob': 0.010977796278893948},
#   {'id': 148,
#    'seek': 75152,
#    'start': 771.12,
#    'end': 776.3199999999999,
#    'text': ' feel massively unstable which you might expect to give that this camera has no optical image stabilisation',
#    'tokens': [51344,
#     841,
#     29379,
#     23742,
#     597,
#     291,
#     1062,
#     2066,
#     281,
#     976,
#     300,
#     341,
#     2799,
#     575,
#     572,
#     20674,
#     3256,
#     11652,
#     7623,
#     51604],
#    'temperature': 0.0,
#    'avg_logprob': -0.1437590843023256,
#    'compression_ratio': 1.900662251655629,
#    'no_speech_prob': 0.010977796278893948},
#   {'id': 149,
#    'seek': 75152,
#    'start': 776.3199999999999,
#    'end': 780.4,
#    'text': " and the focusing isn't jittery which you might expect to give that there's no laser order",
#    'tokens': [51604,
#     293,
#     264,
#     8416,
#     1943,
#     380,
#     361,
#     3904,
#     88,
#     597,
#     291,
#     1062,
#     2066,
#     281,
#     976,
#     300,
#     456,
#     311,
#     572,
#     12530,
#     1668,
#     51808],
#    'temperature': 0.0,
#    'avg_logprob': -0.1437590843023256,
#    'compression_ratio': 1.900662251655629,
#    'no_speech_prob': 0.010977796278893948},
#   {'id': 150,
#    'seek': 78040,
#    'start': 780.4,
#    'end': 785.84,
#    'text': ' focus or anything close to it the hardware of these cameras is nothing special for the price but',
#    'tokens': [50364,
#     1879,
#     420,
#     1340,
#     1998,
#     281,
#     309,
#     264,
#     8837,
#     295,
#     613,
#     8622,
#     307,
#     1825,
#     2121,
#     337,
#     264,
#     3218,
#     457,
#     50636],
#    'temperature': 0.0,
#    'avg_logprob': -0.11745074879039417,
#    'compression_ratio': 1.7802197802197801,
#    'no_speech_prob': 0.004903234075754881},
#   {'id': 151,
#    'seek': 78040,
#    'start': 785.84,
#    'end': 791.1999999999999,
#    'text': " it's the attention to fine tuning what is there that's the reason that you can record footage like this",
#    'tokens': [50636,
#     309,
#     311,
#     264,
#     3202,
#     281,
#     2489,
#     15164,
#     437,
#     307,
#     456,
#     300,
#     311,
#     264,
#     1778,
#     300,
#     291,
#     393,
#     2136,
#     9556,
#     411,
#     341,
#     50904],
#    'temperature': 0.0,
#    'avg_logprob': -0.11745074879039417,
#    'compression_ratio': 1.7802197802197801,
#    'no_speech_prob': 0.004903234075754881},
#   {'id': 152,
#    'seek': 78040,
#    'start': 791.1999999999999,
#    'end': 796.24,
#    'text': " now for me there are four things that I felt have been a bit lacking the color science it's perfectly",
#    'tokens': [50904,
#     586,
#     337,
#     385,
#     456,
#     366,
#     1451,
#     721,
#     300,
#     286,
#     2762,
#     362,
#     668,
#     257,
#     857,
#     20889,
#     264,
#     2017,
#     3497,
#     309,
#     311,
#     6239,
#     51156],
#    'temperature': 0.0,
#    'avg_logprob': -0.11745074879039417,
#    'compression_ratio': 1.7802197802197801,
#    'no_speech_prob': 0.004903234075754881},
#   {'id': 153,
#    'seek': 78040,
#    'start': 796.24,
#    'end': 800.8,
#    'text': " fine with most flowers and objects but it's faces that it really struggles with it's not a",
#    'tokens': [51156,
#     2489,
#     365,
#     881,
#     8085,
#     293,
#     6565,
#     457,
#     309,
#     311,
#     8475,
#     300,
#     309,
#     534,
#     17592,
#     365,
#     309,
#     311,
#     406,
#     257,
#     51384],
#    'temperature': 0.0,
#    'avg_logprob': -0.11745074879039417,
#    'compression_ratio': 1.7802197802197801,
#    'no_speech_prob': 0.004903234075754881},
#   {'id': 154,
#    'seek': 78040,
#    'start': 800.8,
#    'end': 805.84,
#    'text': ' bit small but side by side with a top headphone it becomes very clear how much of that super',
#    'tokens': [51384,
#     857,
#     1359,
#     457,
#     1252,
#     538,
#     1252,
#     365,
#     257,
#     1192,
#     35028,
#     309,
#     3643,
#     588,
#     1850,
#     577,
#     709,
#     295,
#     300,
#     1687,
#     51636],
#    'temperature': 0.0,
#    'avg_logprob': -0.11745074879039417,
#    'compression_ratio': 1.7802197802197801,
#    'no_speech_prob': 0.004903234075754881},
#   {'id': 155,
#    'seek': 80584,
#    'start': 805.84,
#    'end': 810.64,
#    'text': " intelligent fine tuning that you might have come to expect that you're missing out on the portraits",
#    'tokens': [50364,
#     13232,
#     2489,
#     15164,
#     300,
#     291,
#     1062,
#     362,
#     808,
#     281,
#     2066,
#     300,
#     291,
#     434,
#     5361,
#     484,
#     322,
#     264,
#     31880,
#     50604],
#    'temperature': 0.0,
#    'avg_logprob': -0.14706541638855541,
#    'compression_ratio': 1.7421602787456445,
#    'no_speech_prob': 0.004067860543727875},
#   {'id': 156,
#    'seek': 80584,
#    'start': 810.64,
#    'end': 816.1600000000001,
#    'text': " which feel pretty fine in isolation but again next to a top headphone it doesn't take a detective",
#    'tokens': [50604,
#     597,
#     841,
#     1238,
#     2489,
#     294,
#     16001,
#     457,
#     797,
#     958,
#     281,
#     257,
#     1192,
#     35028,
#     309,
#     1177,
#     380,
#     747,
#     257,
#     25571,
#     50880],
#    'temperature': 0.0,
#    'avg_logprob': -0.14706541638855541,
#    'compression_ratio': 1.7421602787456445,
#    'no_speech_prob': 0.004067860543727875},
#   {'id': 157,
#    'seek': 80584,
#    'start': 816.1600000000001,
#    'end': 821.76,
#    'text': " to see the subtle nuances being lost the zooming experience is pretty bad the fact that there's no",
#    'tokens': [50880,
#     281,
#     536,
#     264,
#     13743,
#     38775,
#     885,
#     2731,
#     264,
#     48226,
#     1752,
#     307,
#     1238,
#     1578,
#     264,
#     1186,
#     300,
#     456,
#     311,
#     572,
#     51160],
#    'temperature': 0.0,
#    'avg_logprob': -0.14706541638855541,
#    'compression_ratio': 1.7421602787456445,
#    'no_speech_prob': 0.004067860543727875},
#   {'id': 158,
#    'seek': 80584,
#    'start': 821.76,
#    'end': 826.8000000000001,
#    'text': ' dedicated zoom camera combined with the lack of AI intelligence to know what to do without it means that',
#    'tokens': [51160,
#     8374,
#     8863,
#     2799,
#     9354,
#     365,
#     264,
#     5011,
#     295,
#     7318,
#     7599,
#     281,
#     458,
#     437,
#     281,
#     360,
#     1553,
#     309,
#     1355,
#     300,
#     51412],
#    'temperature': 0.0,
#    'avg_logprob': -0.14706541638855541,
#    'compression_ratio': 1.7421602787456445,
#    'no_speech_prob': 0.004067860543727875},
#   {'id': 159,
#    'seek': 80584,
#    'start': 826.8000000000001,
#    'end': 831.6,
#    'text': ' zooming in 10 times here really does feel that you just took a photo to a one times and blew it up',
#    'tokens': [51412,
#     48226,
#     294,
#     1266,
#     1413,
#     510,
#     534,
#     775,
#     841,
#     300,
#     291,
#     445,
#     1890,
#     257,
#     5052,
#     281,
#     257,
#     472,
#     1413,
#     293,
#     19075,
#     309,
#     493,
#     51652],
#    'temperature': 0.0,
#    'avg_logprob': -0.14706541638855541,
#    'compression_ratio': 1.7421602787456445,
#    'no_speech_prob': 0.004067860543727875},
#   {'id': 160,
#    'seek': 83160,
#    'start': 831.6,
#    'end': 837.9200000000001,
#    'text': " 10 times it's not pretty and then finally there's no ultra wide camera and I can I can kind of see why",
#    'tokens': [50364,
#     1266,
#     1413,
#     309,
#     311,
#     406,
#     1238,
#     293,
#     550,
#     2721,
#     456,
#     311,
#     572,
#     14808,
#     4874,
#     2799,
#     293,
#     286,
#     393,
#     286,
#     393,
#     733,
#     295,
#     536,
#     983,
#     50680],
#    'temperature': 0.0,
#    'avg_logprob': -0.11284889158655385,
#    'compression_ratio': 1.7697841726618706,
#    'no_speech_prob': 0.015644902363419533},
#   {'id': 161,
#    'seek': 83160,
#    'start': 837.9200000000001,
#    'end': 841.76,
#    'text': " because obviously they're not going to have a lot of spare budget to add in a good one and so",
#    'tokens': [50680,
#     570,
#     2745,
#     436,
#     434,
#     406,
#     516,
#     281,
#     362,
#     257,
#     688,
#     295,
#     13798,
#     4706,
#     281,
#     909,
#     294,
#     257,
#     665,
#     472,
#     293,
#     370,
#     50872],
#    'temperature': 0.0,
#    'avg_logprob': -0.11284889158655385,
#    'compression_ratio': 1.7697841726618706,
#    'no_speech_prob': 0.015644902363419533},
#   {'id': 162,
#    'seek': 83160,
#    'start': 841.76,
#    'end': 847.36,
#    'text': ' adding in a cheap one just for the sake of it might make the overall camera feel worse but',
#    'tokens': [50872,
#     5127,
#     294,
#     257,
#     7084,
#     472,
#     445,
#     337,
#     264,
#     9717,
#     295,
#     309,
#     1062,
#     652,
#     264,
#     4787,
#     2799,
#     841,
#     5324,
#     457,
#     51152],
#    'temperature': 0.0,
#    'avg_logprob': -0.11284889158655385,
#    'compression_ratio': 1.7697841726618706,
#    'no_speech_prob': 0.015644902363419533},
#   {'id': 163,
#    'seek': 83160,
#    'start': 847.36,
#    'end': 852.24,
#    'text': ' it is still a lacking feature the key thing to bear in mind though is compare this camera to any phone',
#    'tokens': [51152,
#     309,
#     307,
#     920,
#     257,
#     20889,
#     4111,
#     264,
#     2141,
#     551,
#     281,
#     6155,
#     294,
#     1575,
#     1673,
#     307,
#     6794,
#     341,
#     2799,
#     281,
#     604,
#     2593,
#     51396],
#    'temperature': 0.0,
#    'avg_logprob': -0.11284889158655385,
#    'compression_ratio': 1.7697841726618706,
#    'no_speech_prob': 0.015644902363419533},
#   {'id': 164,
#    'seek': 83160,
#    'start': 852.24,
#    'end': 857.0400000000001,
#    'text': " in its own price range and I would say it's at least as good I just want to make it clear what you're",
#    'tokens': [51396,
#     294,
#     1080,
#     1065,
#     3218,
#     3613,
#     293,
#     286,
#     576,
#     584,
#     309,
#     311,
#     412,
#     1935,
#     382,
#     665,
#     286,
#     445,
#     528,
#     281,
#     652,
#     309,
#     1850,
#     437,
#     291,
#     434,
#     51636],
#    'temperature': 0.0,
#    'avg_logprob': -0.11284889158655385,
#    'compression_ratio': 1.7697841726618706,
#    'no_speech_prob': 0.015644902363419533},
#   {'id': 165,
#    'seek': 85704,
#    'start': 857.04,
#    'end': 862.16,
#    'text': ' not getting so the long and short of it is the CMA phone one is maybe the most instantly',
#    'tokens': [50364,
#     406,
#     1242,
#     370,
#     264,
#     938,
#     293,
#     2099,
#     295,
#     309,
#     307,
#     264,
#     383,
#     9998,
#     2593,
#     472,
#     307,
#     1310,
#     264,
#     881,
#     13518,
#     50620],
#    'temperature': 0.0,
#    'avg_logprob': -0.1733673429026187,
#    'compression_ratio': 1.756554307116105,
#    'no_speech_prob': 0.0022499999031424522},
#   {'id': 166,
#    'seek': 85704,
#    'start': 862.16,
#    'end': 867.76,
#    'text': " recognizable phone I have ever used we've seen this formula before company launches a new sub brand",
#    'tokens': [50620,
#     40757,
#     2593,
#     286,
#     362,
#     1562,
#     1143,
#     321,
#     600,
#     1612,
#     341,
#     8513,
#     949,
#     2237,
#     31841,
#     257,
#     777,
#     1422,
#     3360,
#     50900],
#    'temperature': 0.0,
#    'avg_logprob': -0.1733673429026187,
#    'compression_ratio': 1.756554307116105,
#    'no_speech_prob': 0.0022499999031424522},
#   {'id': 167,
#    'seek': 85704,
#    'start': 867.76,
#    'end': 872.0799999999999,
#    'text': ' company wants to generate hype for that sub brand so company makes the first offering in that',
#    'tokens': [50900,
#     2237,
#     2738,
#     281,
#     8460,
#     24144,
#     337,
#     300,
#     1422,
#     3360,
#     370,
#     2237,
#     1669,
#     264,
#     700,
#     8745,
#     294,
#     300,
#     51116],
#    'temperature': 0.0,
#    'avg_logprob': -0.1733673429026187,
#    'compression_ratio': 1.756554307116105,
#    'no_speech_prob': 0.0022499999031424522},
#   {'id': 168,
#    'seek': 85704,
#    'start': 872.0799999999999,
#    'end': 876.88,
#    'text': " sub brand particularly generous point being it might not stay this way but that doesn't change the",
#    'tokens': [51116,
#     1422,
#     3360,
#     4098,
#     14537,
#     935,
#     885,
#     309,
#     1062,
#     406,
#     1754,
#     341,
#     636,
#     457,
#     300,
#     1177,
#     380,
#     1319,
#     264,
#     51356],
#    'temperature': 0.0,
#    'avg_logprob': -0.1733673429026187,
#    'compression_ratio': 1.756554307116105,
#    'no_speech_prob': 0.0022499999031424522},
#   {'id': 169,
#    'seek': 85704,
#    'start': 876.88,
#    'end': 883.68,
#    'text': ' fact that for what this is right now at this price it feels like a complete steel to me',
#    'tokens': [51356,
#     1186,
#     300,
#     337,
#     437,
#     341,
#     307,
#     558,
#     586,
#     412,
#     341,
#     3218,
#     309,
#     3417,
#     411,
#     257,
#     3566,
#     8269,
#     281,
#     385,
#     51696],
#    'temperature': 0.0,
#    'avg_logprob': -0.1733673429026187,
#    'compression_ratio': 1.756554307116105,
#    'no_speech_prob': 0.0022499999031424522}],
#  'language': 'en'}

# %%
result["text"]
# Out:
# " This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product. CMF is a new budget sub brand of the company nothing so we're talking a phone that costs 200 pounds or 250 dollars and it's actually a little bit crazy what these guys have just pulled off for that price. I mean the first thing I'll notice is this doesn't feel like just a single product launch. This is an entire ecosystem and it's really fascinating one. So let's get the phone out first. There's a Lanyard which is not something you tend to see launch with a phone. One case two cases no three cases a card wallet I guess that's for the back of the phone. There's a stand the Buds Pro 2 and then the watch Pro 2. It all feels very new because we've seen plenty of budget phones before but what you don't often get is a budget accessory ecosystem like this all designed to work specifically around that budget phone as the centerpiece. Everything has well on one hand a slightly cheap thin plastic key feel to it but then on the other hand it's all really tastefully designed. It kind of feels like all of these products have had high end thought and care put into them even if the physical materials and the finish are more basic. So like these are the CMF Buds 2 Pro and even though they're very light and clearly not a luxury item they still feel sophisticated and intentional in their design. Not like a cheap version of something that the company would rather you buy and then the watch Pro 2. Yeah it's slick clean. You never want to watch to go too crazy on design because then it won't match your outfits. So this feels like a pretty appropriate level to me. Right let's get into this phone it's a thin package so we all know what that means. Okay so the device is on top and below that is a generic white USB C to C cable which you should be able to use to transfer everything from the old phone and then an orange sim ejector. Right heel time. And right off the bat it's pretty clear that this is not your normal phone and it's not just that it looks different because you know these cases that I showed you. These are actually back plates. So if you look inside the packaging they came in you'll see a bunch of other stuff like this tool which is both a sim ejector and a screwdriver that allows you to take off these four screws on the back of your phone after which you unwind this circular piece and you're played pops off and this is a pretty big deal for a number of reasons. One that repairing this phone is going to be a lot easier and I hope cheaper than almost any other phone but that part's not confirmed. To that you don't need a case anymore you can actually use your phone naked, guilt-free knowing that if you ever do do something stupid you can just swap the back plate out for, I'm not even that much money, 29 pounds is what they're charging for these kits including the tools. The third thing is it means you can mix a match. So I really like this orange back. It swaps out the slightly cheap feeling very scratchable plastic for a more grippy, less scratchable vegan leather type finish and it's bright orange so let's put it on. But then I'm looking at the orange sim tray, the orange circle screw thing and the silver screws that come with it and thinking silver screws are pretty nice but for the other parts I think I prefer the black ones so I have just created my own two-tone finish on my phone and that's actually sick but the best part of this is that nothing has actually gone one step further to actually create an ecosystem around these weird screws and I don't even know what to call this. Now on this is the circle spinny thing. So if I want a phone stand for example unscrew your circle spinny thing and screw this down then and yeah the standard self isn't anything particularly special. It's not breaking new grounds in material science but if you decide that you want a phone stand then what better way to have a phone stand that doesn't n ...

# %% [markdown]
# # **Using Gemini to get the Transcript**

# %%
# import time

# # Initialize a Gemini model appropriate for your use case.
# model = genai.GenerativeModel(model_name="gemini-1.5-pro")

# # Create the prompt.
# prompt = "Generate a transcript of the speech."

# # Path to the audio file
# audio_file = genai.upload_file(path='/content/audio1.mp3')

# # Start timing
# start_time = time.time()

# # Pass the prompt and the audio file to Gemini.
# response = model.generate_content([prompt, audio_file])

# # End timing
# end_time = time.time()

# # Print the transcript.
# print(response.text)
# print("Processing time:", end_time - start_time, "seconds")
import time

# Initialize a Gemini model appropriate for your use case.
model = genai.GenerativeModel(model_name="gemini-1.5-pro")

# Create the prompt.
prompt = "Generate a transcript of the speech."

# Path to the audio file
audio_file_path = '/content/audio1.mp3'

# Check if the file exists
import os
if not os.path.exists(audio_file_path):
    raise FileNotFoundError(f"File not found: {audio_file_path}")

# Upload the audio file
audio_file = genai.upload_file(path=audio_file_path)

# Start timing
start_time = time.time()

# Pass the prompt and the audio file to Gemini.
try:
    response = model.generate_content([prompt, audio_file])

    # End timing
    end_time = time.time()

    # Print the transcript.
    print(response.text)
    print("Processing time:", end_time - start_time, "seconds")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ERROR:tornado.access:500 POST /v1beta/models/gemini-1.5-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1939.20ms
# An error occurred: 500 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting

# %% [markdown]
# # **Storing the transcript into KB**

# %%
knowledge_base = result["text"]
knowledge_base
# Out:
# " This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product. CMF is a new budget sub brand of the company nothing so we're talking a phone that costs 200 pounds or 250 dollars and it's actually a little bit crazy what these guys have just pulled off for that price. I mean the first thing I'll notice is this doesn't feel like just a single product launch. This is an entire ecosystem and it's really fascinating one. So let's get the phone out first. There's a Lanyard which is not something you tend to see launch with a phone. One case two cases no three cases a card wallet I guess that's for the back of the phone. There's a stand the Buds Pro 2 and then the watch Pro 2. It all feels very new because we've seen plenty of budget phones before but what you don't often get is a budget accessory ecosystem like this all designed to work specifically around that budget phone as the centerpiece. Everything has well on one hand a slightly cheap thin plastic key feel to it but then on the other hand it's all really tastefully designed. It kind of feels like all of these products have had high end thought and care put into them even if the physical materials and the finish are more basic. So like these are the CMF Buds 2 Pro and even though they're very light and clearly not a luxury item they still feel sophisticated and intentional in their design. Not like a cheap version of something that the company would rather you buy and then the watch Pro 2. Yeah it's slick clean. You never want to watch to go too crazy on design because then it won't match your outfits. So this feels like a pretty appropriate level to me. Right let's get into this phone it's a thin package so we all know what that means. Okay so the device is on top and below that is a generic white USB C to C cable which you should be able to use to transfer everything from the old phone and then an orange sim ejector. Right heel time. And right off the bat it's pretty clear that this is not your normal phone and it's not just that it looks different because you know these cases that I showed you. These are actually back plates. So if you look inside the packaging they came in you'll see a bunch of other stuff like this tool which is both a sim ejector and a screwdriver that allows you to take off these four screws on the back of your phone after which you unwind this circular piece and you're played pops off and this is a pretty big deal for a number of reasons. One that repairing this phone is going to be a lot easier and I hope cheaper than almost any other phone but that part's not confirmed. To that you don't need a case anymore you can actually use your phone naked, guilt-free knowing that if you ever do do something stupid you can just swap the back plate out for, I'm not even that much money, 29 pounds is what they're charging for these kits including the tools. The third thing is it means you can mix a match. So I really like this orange back. It swaps out the slightly cheap feeling very scratchable plastic for a more grippy, less scratchable vegan leather type finish and it's bright orange so let's put it on. But then I'm looking at the orange sim tray, the orange circle screw thing and the silver screws that come with it and thinking silver screws are pretty nice but for the other parts I think I prefer the black ones so I have just created my own two-tone finish on my phone and that's actually sick but the best part of this is that nothing has actually gone one step further to actually create an ecosystem around these weird screws and I don't even know what to call this. Now on this is the circle spinny thing. So if I want a phone stand for example unscrew your circle spinny thing and screw this down then and yeah the standard self isn't anything particularly special. It's not breaking new grounds in material science but if you decide that you want a phone stand then what better way to have a phone stand that doesn't n ...

# %% [markdown]
# # **Using Gemini 1.5 flash for response generatinon**

# %%
# Taking question as input
question = input("Enter your question: ")
# Out:
# Enter your question: What is the cost of the phone

# %%
# Initialize a Gemini model appropriate for your use case.
model = genai.GenerativeModel(model_name="gemini-1.5-flash")

# Defining promt for the required response
promt = """You are an expert in finding answers or matching answers for the asked question from the Knowledge Base Given below.
           Your task is to analyze the complete Knowledge Base and answer the questions asked.
           The Knowledge Base is : """ + knowledge_base + """The Question is""" + question + """ The Output Must be like Question:<Asked Question> And in new Line Answer: <Answer Generated>"""

# Pass the prompt and the audio file to Gemini.
response = model.generate_content([promt])

# Print the transcript.
print(response.text)
# Out:
# Question: What is the cost of the phone?
# Answer: 200 pounds or 250 dollars.

# %% [markdown]
# # **Generating Multiple Questions for the KB**

# %%
n_questions = input("Enter the number of questions you want to generate: ")
# Out:
# Enter the number of questions you want to generate: 10

# %%
# Defining promt for the required response
questions_promt = """You are an expert in framing the number of questions asked.
           Your task is to analyze the complete Knowledge Base and generate the number of questions asked.
           The Knowledge Base is : """ + knowledge_base + """The Number of Questions need to be Generated is""" + n_questions + """The output must be 1.<Question1> 2.<Question2> 3.<Question3> upto specified number of questions And provide answer for the question."""

# Pass the prompt and the audio file to Gemini.
question_response = model.generate_content([questions_promt])

# Print the transcript.
print(question_response.text)
# Out:
# Here are 10 questions generated from the provided text, along with potential answers based on the text's content:
#
# 1. **<Question1> What is the CMF phone one's unique feature that allows for customization and easy repair?**
#    * **Answer:** The CMF phone one features interchangeable back plates that can be easily removed and replaced with a screwdriver. This allows for customization by mixing and matching colors and finishes, as well as making repairs more accessible and potentially less expensive.
#
# 2. **<Question2> How does the CMF phone one's design philosophy differ from the Nothing phone (1)?**
#    * **Answer:** While the Nothing phone (1) prioritizes a minimalist design with LED lights, the CMF phone one focuses on a more customizable and modular design. It prioritizes functionality and practicality, offering features like interchangeable back plates and screw-on accessories. This approach allows for a greater degree of personalization without compromising on affordability.
#
# 3. **<Question3> What are the compromises made in the CMF phone one in terms of performance and hardware compared to higher-end phones?**
#    * **Answer:** The CMF phone one compromises on performance with a less powerful MediaTek Dimensity 7300 chipset.  It also lacks features like wireless charging, a dedicated telephoto lens, and optical image stabilization.  These compromises are likely made to maintain the phone's affordability while still delivering a competitive experience.
#
# 4. **<Question4> What are the strengths of the CMF phone one's camera system, especially considering its price point?**
#    * **Answer:** The CMF phone one's camera system excels in providing good detail, dynamic range, and video quality for its price. Despite lacking a dedicated telephoto lens, it manages to deliver decent zoom performance, and the video recording is surprisingly stable and noise-free. The camera's strengths are a result of careful fine-tuning and software optimization.
#
# 5. **<Question5> What are the weaknesses of the CMF phone one's camera system, and how do they compare to other phones in its price range?**
#    * **Answer:** The CMF phone one's camera system falls short in color accuracy, especially with skin tones, compared to higher-end phones. The lack of a dedicated telephoto lens and the absence of a wide-angle lens are also notable weaknesses.  However, the overall performance is still competitive within its price range.
#
# 6. **<Question6> What is the CMF phone one's battery life like, and how does it compare to the Nothing phone (1)?**
#    * **Answer:** The CMF phone one boasts a 5000 mAh battery, which the reviewer claims provides excellent battery life. This outperforms the Nothing phone (1) in terms of battery life, even with the smaller chipset. The reviewer suggests the phone's battery efficiency stems from the efficient chipset, lightweight software, and the AMOLED screen's ability to turn off black pixels.
#
# 7. **<Question7> What is the CMF phone one's software experience like, and what are some notable features?**
#    * **Answer:** The CMF phone one runs Nothing OS 2.6 based on Android 14, which is described as a light and non-intrusive skin.  Notable features include a wallpaper generator tool, two years of major Android updates, and three years of security updates. This software experience is considered to be fairly standard for its price range.
#
# 8. **<Question8> What is the significance of the name "CMF" for this phone and its sub-brand?**
#    * **Answer:** The name "CMF" stands for "Colors, Materials, and Finish."  It reflects the brand's focus on designing visually appealing products with a strong emphasis on the material quality and finish. This resonates with the CMF phone one's emphasis on customization and its overall design philosophy.
#
# 9. **<Question9> What are the reviewer's overall impressions of the CMF phone one, and what is the core takeaway?**
#    * **Answer:** The reviewer believes the CMF phone one is an exceptionally well-designed phone for its price, particularly considering its modular design and customization options.  The reviewer praises the phone's design, battery life, and camera performance, highlighting its value for money.
#
# 10. **<Question10> What is the reviewer's biggest criticism of the CMF phone one, and what is their reasoning?**
#    * **Answer:** The reviewer's biggest criticism is the phone's inability to replace the battery, despite its easily removable back plate. They see this as a missed opportunity to further enhance the phone's repairability and user customization.

# %% [markdown]
# # **Summarizing the transcript of the YouTube video**

# %%
# Specifing the Summarizing prompt
summary_promt = """You are an expert in English Language
                   Now your task is to summarize the given content into 250 words and remove any gramatical mistakes.
                   The summary is :-""" + knowledge_base + """ Generate the Important points in each line"""

# Pass the prompt and the audio file to Gemini.
summary_response = model.generate_content([summary_promt])

# Print the transcript.
print(summary_response.text)
# Out:
# The Nothing CMF Phone 1 is a budget-friendly smartphone that packs a surprising amount of value for its price. Its biggest strength is its modular design, allowing users to swap back plates, customize the look, and even add accessories like stands and lanyards using a unique screw system. This innovative approach delivers high functionality without compromising cost.
#
# While the screen boasts a smooth 120Hz refresh rate and a punchy display, the phone's performance is average, relying on a MediaTek Dimensity 7300 chipset. While it can handle most tasks, demanding games may require lower settings for optimal performance. The battery life, however, is exceptional, exceeding 10 hours of screen-on time.
#
# The camera system, surprisingly good for this price range, features a dual-lens setup with a primary sensor that captures detailed images. The lack of a dedicated zoom lens and ultra-wide camera are notable omissions, but the overall camera performance is commendable considering the budget.
#
# Ultimately, the CMF Phone 1 shines in its innovative design and exceptional value proposition.  While it may not excel in every area, it offers a unique and compelling experience for budget-conscious consumers looking for a well-designed and functional smartphone.

# %% [markdown]
# # **Generating the MCQs questons for it.**

# %%
mcqs_prompt = """You are an expert in framing the number of MCQ questions asked.
           Your task is to analyze the complete Knowledge Base and generate the number of questions asked.
           The Knowledge Base is : """ + knowledge_base + """The Number of Questions need to be Generated is""" + n_questions + """The output must be 1.<Question1> a. opt1 b. op2 c. opt3 d. opt4  2.<Question2>a. opt1 b. op2 c. opt3 d. opt4 3.<Question3>a. opt1 b. op2 c. opt3 d. opt4 upto specified number of questions"""

# Pass the prompt and the audio file to Gemini.
mcqs_response = model.generate_content([mcqs_prompt])

# Print the transcript.
print(mcqs_response.text)
# Out:
# ##  CMF Phone One MCQ Questions
#
# **1. What is the main selling point of the CMF Phone One, according to the text?**
#
# a. Its powerful processor and large RAM.
# b. Its exceptional camera quality.
# c. Its customizable design and modular features.
# d. Its budget-friendly price point and feature-rich ecosystem.
#
# **2. What is the name of the company behind the CMF Phone One?**
#
# a. Nothing
# b. CMF
# c. Google
# d. Samsung
#
# **3. What is the significance of the CMF Phone One's backplate being removable?**
#
# a. It allows for easy battery replacement.
# b. It enables the phone to be repaired more easily.
# c. It makes the phone waterproof.
# d. It enables the phone to be used without a case.
#
# **4. What is the primary purpose of the "circle spinny thing" on the CMF Phone One?**
#
# a. To enable wireless charging.
# b. To provide additional storage space.
# c. To act as a stand for the phone.
# d. To enhance the phone's camera capabilities.
#
# **5. Which of the following features is NOT available on the CMF Phone One?**
#
# a. Wireless charging
# b. In-display fingerprint scanner
# c. 120Hz display refresh rate
# d. Expandable storage
#
# **6. What is the name of the chipset used in the CMF Phone One?**
#
# a. Qualcomm Snapdragon 8 Gen 2
# b. MediaTek Dimensity 7300
# c. Apple A16 Bionic
# d. Samsung Exynos 2200
#
# **7. Which of the following statements about the CMF Phone One's camera is TRUE?**
#
# a. It has a triple-camera system.
# b. It lacks an ultra-wide camera.
# c. It features a periscope telephoto lens.
# d. It has a dedicated macro camera.
#
# **8. What is the main difference between the Nothing Phone (1) and the CMF Phone One?**
#
# a. The Nothing Phone (1) has a more powerful processor.
# b. The CMF Phone One has a more customizable design.
# c. The CMF Phone One is more expensive.
# d. The Nothing Phone (1) has a better camera system.
#
# **9. What does the term "CMF" stand for in the context of the CMF Phone One?**
#
# a. Color, Material, and Finish
# b. Customized, Modular, and Functional
# c. Compact, Modern, and Flexible
# d. Creative, Minimalist, and Fast
#
# **10. What is the overall impression of the CMF Phone One based on the text?**
#
# a. A disappointing phone with major flaws.
# b. A surprisingly good phone for its price.
# c. A revolutionary phone that surpasses expectations.
# d. A mediocre phone that offers nothing unique.

# %% [markdown]
# # **Export into PDF**

# %% [markdown]
# # **Test Purpose Not fully Implemented from here**

# %% [markdown]
# # **RAG Implementation for above approach along with Gemini API**

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.23.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-3.0.1

# %%
import google.generativeai as genai
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Configure the Gemini API
genai.configure(api_key="AIzaSyAIewGMqAtMEtZMZjDJgEPNEwh_Q74yfGw")

# Initialize the Gemini model
model = genai.GenerativeModel(model_name="gemini-1.5-flash")

# Initialize the sentence transformer model for embedding
sentence_model = SentenceTransformer('all-MiniLM-L6-v2')

# Split the knowledge base into chunks
def split_into_chunks(text, chunk_size=100):
    words = text.split()
    return [' '.join(words[i:i+chunk_size]) for i in range(0, len(words), chunk_size)]

chunks = split_into_chunks(knowledge_base)

# Create embeddings for all chunks
chunk_embeddings = sentence_model.encode(chunks)

def get_most_relevant_chunk(query, top_k=3):
    query_embedding = sentence_model.encode([query])
    similarities = cosine_similarity(query_embedding, chunk_embeddings)[0]
    top_indices = np.argsort(similarities)[-top_k:][::-1]
    return [chunks[i] for i in top_indices]

def rag_query(query):
    relevant_chunks = get_most_relevant_chunk(query)
    context = "\n".join(relevant_chunks)

    prompt = f"""You are an AI assistant trained to answer questions based on the given context.
    Use the following context to answer the question. If the answer is not in the context, say "I don't have enough information to answer this question."

    Context: {context}

    Question: {query}

    Answer:"""

    response = model.generate_content([prompt])
    return context, response.text

# Example usage
while True:
    question = input("Enter your question (or 'quit' to exit): ")
    if question.lower() == 'quit':
        break
    context, answer = rag_query(question)
    print(f"Question: {question}")
    print(f"Context:\n{context}\n")
    print(f"Answer: {answer}\n")
    print("-" * 50)  # Separator for readability
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Enter your question (or 'quit' to exit): quit

# %%
# chunk_embeddings

# %%
# chunks

# %% [markdown]
# # **Implementation of RAG for above using FAISS and cosine similarity**

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0.post1

# %%
# Import the required modules
import faiss
import pickle
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
# Create a FAISS index
dimension = chunk_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(chunk_embeddings.astype('float32'))

# %%
print(f"Dimension: {dimension}")
print(f"Index: {index}")
# Out:
# Dimension: 384
# Index: <faiss.swigfaiss_avx512.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x7c30914c6e50> >

# %%
# Store the chunks and their IDs
chunk_dict = {i: chunk for i, chunk in enumerate(chunks)}

# %%
# chunk_dict

# %%
# Save the index and chunk dictionary
faiss.write_index(index, "transcript_index.faiss")
with open("chunk_dict.pkl", "wb") as f:
    pickle.dump(chunk_dict, f)

# %%
def load_vector_db():
    # Load the index and chunk dictionary
    index = faiss.read_index("transcript_index.faiss")
    with open("chunk_dict.pkl", "rb") as f:
        chunk_dict = pickle.load(f)
    return index, chunk_dict

# %%
def get_most_relevant_chunk(query, index, chunk_dict, top_k=3):
    query_embedding = sentence_model.encode([query]).astype('float32')
    distances, indices = index.search(query_embedding, top_k)
    return [chunk_dict[int(i)] for i in indices[0]]

# %%
def rag_query(query, index, chunk_dict):
    relevant_chunks = get_most_relevant_chunk(query, index, chunk_dict)
    context = "\n".join(relevant_chunks)

    prompt = f"""You are an AI assistant trained to answer questions based on the given context.
    Use the following context to answer the question. If the answer is not in the context, say "I don't have enough information to answer this question."

    Context: {context}

    Question: {query}

    Answer:"""

    response = model.generate_content([prompt])
    return context, response.text

# %%
# Load the vector database
index, chunk_dict = load_vector_db()

# %%
print(f"Index: {index}")
print(f"Chunk Dictionary: {chunk_dict}")
# Out:
# Index: <faiss.swigfaiss_avx512.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x7c3091bcd3e0> >
# Chunk Dictionary: {0: "This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product. CMF is a new budget sub brand of the company nothing so we're talking a phone that costs 200 pounds or 250 dollars and it's actually a little bit crazy what these guys have just pulled off for that price. I mean the first thing I'll notice is this doesn't feel like just a single product launch. This is an entire ecosystem and it's really fascinating one. So let's get the phone out first. There's a Lanyard", 1: "which is not something you tend to see launch with a phone. One case two cases no three cases a card wallet I guess that's for the back of the phone. There's a stand the Buds Pro 2 and then the watch Pro 2. It all feels very new because we've seen plenty of budget phones before but what you don't often get is a budget accessory ecosystem like this all designed to work specifically around that budget phone as the centerpiece. Everything has well on one hand a slightly cheap thin plastic key feel to it but then on", 2: "the other hand it's all really tastefully designed. It kind of feels like all of these products have had high end thought and care put into them even if the physical materials and the finish are more basic. So like these are the CMF Buds 2 Pro and even though they're very light and clearly not a luxury item they still feel sophisticated and intentional in their design. Not like a cheap version of something that the company would rather you buy and then the watch Pro 2. Yeah it's slick clean. You never want to watch to go too", 3: "crazy on design because then it won't match your outfits. So this feels like a pretty appropriate level to me. Right let's get into this phone it's a thin package so we all know what that means. Okay so the device is on top and below that is a generic white USB C to C cable which you should be able to use to transfer everything from the old phone and then an orange sim ejector. Right heel time. And right off the bat it's pretty clear that this is not your normal phone and it's not just that it", 4: "looks different because you know these cases that I showed you. These are actually back plates. So if you look inside the packaging they came in you'll see a bunch of other stuff like this tool which is both a sim ejector and a screwdriver that allows you to take off these four screws on the back of your phone after which you unwind this circular piece and you're played pops off and this is a pretty big deal for a number of reasons. One that repairing this phone is going to be a lot easier and I hope cheaper", 5: "than almost any other phone but that part's not confirmed. To that you don't need a case anymore you can actually use your phone naked, guilt-free knowing that if you ever do do something stupid you can just swap the back plate out for, I'm not even that much money, 29 pounds is what they're charging for these kits including the tools. The third thing is it means you can mix a match. So I really like this orange back. It swaps out the slightly cheap feeling very scratchable plastic for a more grippy, less scratchable vegan leather type finish", 6: "and it's bright orange so let's put it on. But then I'm looking at the orange sim tray, the orange circle screw thing and the silver screws that come with it and thinking silver screws are pretty nice but for the other parts I think I prefer the black ones so I have just created my own two-tone finish on my phone and that's actually sick but the best part of this is that nothing has actually gone one step further to actually create an ecosystem around these weird screws and I don't even know what to call this. Now", 7: "on this is the circle spinny thing. So if I want a phone stand for example unscrew your circle spinny thing and screw this down then and yeah the standard self isn't anything particularly special. It's not breaking new grounds in material science but if you decide that you want a phone  ...

# %%
# Example usage
while True:
    question = input("Enter your question (or 'quit' to exit): ")
    if question.lower() == 'quit':
        break
    context, answer = rag_query(question, index, chunk_dict)
    print(f"Question: {question}")
    print(f"Context:\n{context}\n")
    print(f"Answer: {answer}\n")
    print("-" * 50)  # Separator for readability
# Out:
# Enter your question (or 'quit' to exit): quit

# %% [markdown]
# # **Implementing only RAG without Gemini API to test the accuracy in the response**

# %%
# Import the required modules
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Preprocess the knowledge base
def preprocess(text):
    sentences = sent_tokenize(text)
    stop_words = set(stopwords.words('english'))
    processed_sentences = []
    for sentence in sentences:
        words = word_tokenize(sentence.lower())
        words = [word for word in words if word.isalnum() and word not in stop_words]
        processed_sentences.append(' '.join(words))
    return processed_sentences

# %%
processed_kb = preprocess(knowledge_base)
processed_kb
# Out:
# ['new nothing cmf phone one say often think genius product',
#  'cmf new budget sub brand company nothing talking phone costs 200 pounds 250 dollars actually little bit crazy guys pulled price',
#  'mean first thing notice feel like single product launch',
#  'entire ecosystem really fascinating one',
#  'let get phone first',
#  'lanyard something tend see launch phone',
#  'one case two cases three cases card wallet guess back phone',
#  'stand buds pro 2 watch pro 2',
#  'feels new seen plenty budget phones often get budget accessory ecosystem like designed work specifically around budget phone centerpiece',
#  'everything well one hand slightly cheap thin plastic key feel hand really tastefully designed',
#  'kind feels like products high end thought care put even physical materials finish basic',
#  'like cmf buds 2 pro even though light clearly luxury item still feel sophisticated intentional design',
#  'like cheap version something company would rather buy watch pro 2',
#  'yeah slick clean',
#  'never want watch go crazy design wo match outfits',
#  'feels like pretty appropriate level',
#  'right let get phone thin package know means',
#  'okay device top generic white usb c c cable able use transfer everything old phone orange sim ejector',
#  'right heel time',
#  'right bat pretty clear normal phone looks different know cases showed',
#  'actually back plates',
#  'look inside packaging came see bunch stuff like tool sim ejector screwdriver allows take four screws back phone unwind circular piece played pops pretty big deal number reasons',
#  'one repairing phone going lot easier hope cheaper almost phone part confirmed',
#  'need case anymore actually use phone naked knowing ever something stupid swap back plate even much money 29 pounds charging kits including tools',
#  'third thing means mix match',
#  'really like orange back',
#  'swaps slightly cheap feeling scratchable plastic grippy less scratchable vegan leather type finish bright orange let put',
#  'looking orange sim tray orange circle screw thing silver screws come thinking silver screws pretty nice parts think prefer black ones created finish phone actually sick best part nothing actually gone one step actually create ecosystem around weird screws even know call',
#  'circle spinny thing',
#  'want phone stand example unscrew circle spinny thing screw yeah standard self anything particularly special',
#  'breaking new grounds material science decide want phone stand better way phone stand need apply sticky pad onto case instead physically screws device',
#  'feels way secure also way intentional like stand designed specifically phone',
#  'want lanyard thing feel confident going support phone bolted like magsafe wireless charging baked phone right ca slap one apple wallets onto back expect hold screw cmf wallet enclosure like secure magnet able attach wallet top thing hold like three cards whole thing reminds much mentality discovered india called jagad means uh frugal innovation inventive ways use achieve things would normally require resources properly thinking building company genuinely achieved really high level functionality without making cost build thing actually getting something ca get paying nose higher end device like nothing managed make something gives 250 phone tangible leg 1200 phone absolutely amazing mind kind wearing possibilities like thinking example use screw screw add permanent lens attachment cameras know instead ones clip anything light breeze remove would personally little bit worried things getting inside managed get ipx true rating basically minor water protection nothing dust think somewhat telling max rating could get yeah anything designed taken apart easily obviously particularly well sealed also cool circles anything find little bit uncomfortable sticks let clear price one best designed phones ever seen half surprised entire name sub brand cmf literally stands colors materials finish actually rest phone surprised let talk winning design 250 losing well screen 120 hertz adaptive ammo led full hd plus display smooth sharp punchy thing display hdr 10 plus content luxury could get paying thousand dollars like literally two years ago screen protector always rate right optical fingerprint scanner well fine works even brightness one first things go actually pretty good company advertising 2000 net peak brightness need achieve specific situations typically thing go max 700 nets normal brightness 1200 nets ultra bright outdoor environments means absolute worst worst case scenarios might squint little bit pretty much never struggle see thing would complain quite nitpicky bottom bezel slightly thicker bezels particularly interesting remember conversation carl pay ceo launched nothing phone basically explaining much extra effort cost engineering required push bottom lip tiny little bit even made decision still expensive nothing vence looking phone basically half cost guess decided let design ideologies slip little bit fair compromise though still ca think better screen 250 dollars sure compromise battery phone 5000 million power cell chip actually based efficient enemy process software skin light thanks thousands apps installed top also noticed set phone dark mode default black icons good ammo led display turn anywhere displaying black pixels point doubt mind gracefully carried day thing like pull battery settings saying four hours screen time still 60 battery currently track thing lasting 10 hours screen time charge ever going need',
#  'weird thing even though phone stupidly easy take apart still ca actually swap battery decided existing one getting old feels like missed opportunity charging situation okay wireless charging wire charging pretty mediocre 33 watts since get charging grip achieve wattage imagine people operating important thing battery life battery life nailed compromising software either phone runs nothing os based android 14 love software skin light interfere much stock android already well little thoughtful things either make phone aesthetic make less distracting ai generator tool wallpapers quite limited options would nice could least specify colour wanted equally turn reliably good results never seem look ai generated mean getting two years major android updates three years security updates doubt big part money saved compared expensive nothing two example bad level support pretty standard tier nothing spectacular chip inside phone biggest wildcard idea expect phone got six gigabytes ram base model 128 gigs storage interestingly expandable storage two terabyte sd card paired media tech chip set dimensity 7300 reason know expect well least paper dimensity 7300 actually less powerful 7200 someone please explain math anyway looks like practice latest game hoyovers company made genshin impact providing game mode access swiping left play pretty acceptable frame rate hovering mostly high settings even though liquid cooling system inside noticed performance declining prolonged gaming want get lag get stable experience go medium settings factor demanding mobile games get anything wo able play make noticeable compromises help games look basis feel slow also feel particularly fast phone mostly smooth occasional jitter every thing noticed every time click something open app try load something takes little bit time like waiting around fraction thinking time action would expected anything different phone price really actually phone good makes forget much costs actually mind benchmarking much expensive prices audio probably obvious downgrade noticed simple mono speaker bottom get kind stereo effect using earpiece second speaker lose little bit sophistication music listening also would go far say bad speaker actually rather loud really came cameras nothing managed done also smash cameras thing going straight whole fame equally expecting big noticeable dip phone experience slowly approached camera button fully ready lose chunk respect device know mad lads kind done phone two cameras little bit weird one top camera actually sister camera hold finger still perform basically every single function phone camera thing ca without add portrait mode effect shots take photo covering lens look like take photo removed finger look like photos look like well nicely detailed plenty room zoom still look sharp wide aperture decent sensor size gets nice foreground background separation mostly flawless high dynamic range say mostly absolutely spot big scenes overexposed sky often misses small things like bright light bulb shop needs controlling know video right look decent phone shoots 4k footage 30 frames per second feel particularly noisy might expect since phone chip best image signal processor feel massively unstable might expect give camera optical image stabilisation focusing jittery might expect give laser order focus anything close hardware cameras nothing special price attention fine tuning reason record footage like four things felt bit lacking color science perfectly fine flowers objects faces really struggles bit small side side top headphone becomes clear much super intelligent fine tuning might come expect missing portraits feel pretty fine isolation next top headphone take detective see subtle nuances lost zooming experience pretty bad fact dedicated zoom camera combined lack ai intelligence know without means zooming 10 times really feel took photo one times blew 10 times pretty finally ultra wide camera kind see obviously going lot spare budget add good one ...

# %%
# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed_kb)

# %%
# tfidf_matrix

# %%
def get_most_relevant_sentence(query):
    query_vector = vectorizer.transform([query])
    similarities = cosine_similarity(query_vector, tfidf_matrix)
    most_similar_idx = np.argmax(similarities)
    return sent_tokenize(knowledge_base)[most_similar_idx]

# %%
def answer_question(question):
    relevant_sentence = get_most_relevant_sentence(question)
    return f"Based on the information provided: {relevant_sentence}"

# %%
# Main loop
while True:
    user_question = input("Ask a question about the Nothing CMF phone (or type 'exit' to quit): ")
    if user_question.lower() == 'exit':
        break
    answer = answer_question(user_question)
    print(answer)
    print()
# Out:
# Ask a question about the Nothing CMF phone (or type 'exit' to quit): quit
# Based on the information provided:  This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product.
#
# Ask a question about the Nothing CMF phone (or type 'exit' to quit): quit
# Based on the information provided:  This is the new Nothing CMF phone one and I don't say this very often but I think this is a genius product.
#
# Ask a question about the Nothing CMF phone (or type 'exit' to quit): exit

# %% [markdown]
# # **Based on the above understanding, we must use both the RAG Application along with the LLM to provide much more accurate results. If we use only the RAG, we can't get the optimal results. By using RAG along with the Gemini API, we provide extra context that the answer mostly lies in the context for which the searching for the appropriate query time taken will be very less.**
